# %%
import pandas as pd

situacao_final = pd.read_excel(r'C:\Users\estoque\Documents\estoque.renan\projetos\projeto_curva_abc\tratamento_curva_abc\dados_tratados/situacao_final.xlsx')
enderecos = situacao_final[['Ender.Cx.Fechada']].astype(str)

display(enderecos)

locais = pd.read_excel(r'C:\Users\estoque\Documents\estoque.renan\projetos\projeto_curva_abc\tratamento_curva_abc\datasets/local_apanha_cx.xlsx').astype(str)

display(locais)
# Out:
#      Ender.Cx.Fechada
# 0       018-023-00-02
# 1       017-034-01-01
# 2       018-027-01-01
# 3       018-021-01-01
# 4       018-029-00-02
# ...               ...
# 9426              nan
# 9427              nan
# 9428              nan
# 9429              nan
# 9430              nan
#
# [9431 rows x 1 columns]
#     Ender.Cx.Fechada       local
# 0      014-006-01-01      fech_a
# 1      014-006-01-02      fech_a
# 2      014-008-01-01      fech_a
# 3      014-008-01-02      fech_a
# 4      014-010-01-01      fech_a
# ..               ...         ...
# 478    018-006-01-02  controlado
# 479    018-007-01-01  controlado
# 480    018-007-01-02  controlado
# 481    018-008-01-01  controlado
# 482    018-008-01-02  controlado
#
# [483 rows x 2 columns]

# %%
def refatorar_indece(df, nome_index):
    
    qnt_linha = df.shape[0] + 1

    index = [i for i in range(1, qnt_linha)]

    df.set_index(pd.Index(index), inplace=True)

    df.index.name = nome_index
    
    return df

# %%
enderecos_x_locais = pd.merge(enderecos, locais)
enderecos_x_locais
# Out:
#      Ender.Cx.Fechada   local
# 0       018-023-00-02      fd
# 1       017-034-01-01      fd
# 2       017-034-01-01      fd
# 3       018-027-01-01      fd
# 4       018-027-01-01      fd
# ...               ...     ...
# 3210    016-005-01-01  fech_a
# 3211    016-005-01-01  fech_a
# 3212    016-005-01-01  fech_a
# 3213    016-005-01-01  fech_a
# 3214    014-008-02-02  fech_a
#
# [3215 rows x 2 columns]

# %%
total_enderecos_usados = enderecos.drop_duplicates()
total_enderecos_usados
# Out:
#      Ender.Cx.Fechada
# 0       018-023-00-02
# 1       017-034-01-01
# 2       018-027-01-01
# 3       018-021-01-01
# 4       018-029-00-02
# ...               ...
# 3270    010-020-02-01
# 3388    018-020-00-02
# 3400    016-005-01-01
# 4250    010-042-01-01
# 8995    014-008-02-02
#
# [472 rows x 1 columns]

# %%
item_com_end = ~(enderecos['Ender.Cx.Fechada'] == 'nan')

# %%
item_com_end
enderecos[item_com_end]
# Out:
#      Ender.Cx.Fechada
# 0       018-023-00-02
# 1       017-034-01-01
# 2       018-027-01-01
# 3       018-021-01-01
# 4       018-029-00-02
# ...               ...
# 9403    017-019-01-01
# 9414    012-052-02-02
# 9415    018-001-01-02
# 9416    018-004-01-02
# 9419    018-006-01-01
#
# [3274 rows x 1 columns]

# %%
situacao_final
# Out:
#       Ordem  Código                              Descrição Curva Frac  \
# 0         1   60342           FD INF VIC BABY MEGA EG 3X70          B
# 1         2   60341           FD INF VIC BABY MEGA G 03X80          B
# 2         3   60321  FD INF MULTIFRAL SUPER JUMBO EG 03X70          B
# 3         4   60343          FD INF VIC BABY MEGA XXG 3X56          B
# 4         5   60320   FD INF MULTIFRAL SUPER JUMBO G 03X80          B
# ...     ...     ...                                    ...        ...
# 9426   9427  549039                                      -          C
# 9427   9428  549047                                      -          C
# 9428   9429  549487                                      -          C
# 9429   9430  549494                                      -          C
# 9430   9431  549531                                      -          C
#
#      Curva Cx Curva Geral  Qtde Venda Frac  Qtde Venda Cx  Qtde Venda Geral  \
# 0           A           A            165.0         9874.0            9874.0
# 1           A           A            160.0         9481.0            9481.0
# 2           A           A            172.0         9402.0            9402.0
# 3           A           A            193.0         9041.0            9041.0
# 4           A           A            138.0         7926.0            7926.0
# ...       ...         ...              ...            ...               ...
# 9426      NaN         NaN              1.0            NaN               NaN
# 9427      NaN         NaN              1.0            NaN               NaN
# 9428      NaN         NaN              1.0            NaN               NaN
# 9429      NaN         NaN              1.0            NaN               NaN
# 9430      NaN         NaN              1.0            NaN               NaN
#
#       Dias Pedido Frac  ...  Estoque Armaz.  Ender.Cx.Fechada  Estoque Frac  \
# 0                 68.0  ...          1713.0     018-023-00-02           8.0
# 1                 59.0  ...          1622.0     017-034-01-01           3.0
# 2                 47.0  ...             0.0     018-027-01-01           0.0
# 3                 71.0  ...          1779.0     018-021-01-01           6.0
# 4                 50.0  ...             0.0     018-029-00-02           0.0
# ...                ...  ...             ...               ...           ...
# 9426               1.0  ...             NaN               NaN           NaN
# 9427               1.0  ...             NaN               NaN           NaN
# 9428               1.0  ...             NaN               NaN           NaN
# 9429               1.0  ...             NaN               NaN           NaN
# 9430               1.0  ...             NaN               NaN           NaN
#
#       Capacidade Frac  Embal.  Permite Frac.  Apanha Frac  Ender.Fracionado  \
# 0                 8.0     3.0            Sim          Sim            29.223
# 1                 3.0     3.0            Sim          Sim            29.221
# 2                 8.0     3.0            Sim          Sim            29.512
# 3                 6.0     3.0            Sim          Sim            29.575
# 4                 0.0     3.0            Sim          Não               NaN
# ...               ...     ...            ...          ...               ...
# 9426              NaN     NaN            NaN          NaN               NaN
# 9427              NaN     NaN            NaN          NaN               NaN
# 9428              NaN     NaN            NaN          NaN               NaN
# 9429              NaN     NaN            NaN          NaN               NaN
# 9430              NaN     NaN            NaN          NaN               NaN
#
#             Tipo Qtde Desvio Picking
# 0     Prateleira                21.0
# 1     Prateleira                29.0
# 2     Prateleira                 6.0
# 3     Prateleira                19.0
# 4            NaN                17.0
# ...          ...                 ...
# 9426         NaN                 0.0
# 9427         NaN                 0.0
# 9428         NaN                 0.0
# 9429         NaN                 0.0
# 9430         NaN                 0.0
#
# [9431 rows x 28 columns]

# %%
teste = pd.merge(situacao_final, enderecos_x_locais, how = 'left')

# %%
teste
# Out:
#        Ordem  Código                              Descrição Curva Frac  \
# 0          1   60342           FD INF VIC BABY MEGA EG 3X70          B
# 1          2   60341           FD INF VIC BABY MEGA G 03X80          B
# 2          2   60341           FD INF VIC BABY MEGA G 03X80          B
# 3          3   60321  FD INF MULTIFRAL SUPER JUMBO EG 03X70          B
# 4          3   60321  FD INF MULTIFRAL SUPER JUMBO EG 03X70          B
# ...      ...     ...                                    ...        ...
# 46126   9427  549039                                      -          C
# 46127   9428  549047                                      -          C
# 46128   9429  549487                                      -          C
# 46129   9430  549494                                      -          C
# 46130   9431  549531                                      -          C
#
#       Curva Cx Curva Geral  Qtde Venda Frac  Qtde Venda Cx  Qtde Venda Geral  \
# 0            A           A            165.0         9874.0            9874.0
# 1            A           A            160.0         9481.0            9481.0
# 2            A           A            160.0         9481.0            9481.0
# 3            A           A            172.0         9402.0            9402.0
# 4            A           A            172.0         9402.0            9402.0
# ...        ...         ...              ...            ...               ...
# 46126      NaN         NaN              1.0            NaN               NaN
# 46127      NaN         NaN              1.0            NaN               NaN
# 46128      NaN         NaN              1.0            NaN               NaN
# 46129      NaN         NaN              1.0            NaN               NaN
# 46130      NaN         NaN              1.0            NaN               NaN
#
#        Dias Pedido Frac  ...  Ender.Cx.Fechada  Estoque Frac  Capacidade Frac  \
# 0                  68.0  ...     018-023-00-02           8.0              8.0
# 1                  59.0  ...     017-034-01-01           3.0              3.0
# 2                  59.0  ...     017-034-01-01           3.0              3.0
# 3                  47.0  ...     018-027-01-01           0.0              8.0
# 4                  47.0  ...     018-027-01-01           0.0              8.0
# ...                 ...  ...               ...           ...              ...
# 46126               1.0  ...               NaN           NaN              NaN
# 46127               1.0  ...               NaN           NaN              NaN
# 46128               1.0  ...               NaN           NaN              NaN
# 46129               1.0  ...               NaN           NaN              NaN
# 46130               1.0  ...               NaN           NaN              NaN
#
#        Embal.  Permite Frac.  Apanha Frac  Ender.Fracionado        Tipo  \
# 0         3.0            Sim          Sim            29.223  Prateleira
# 1         3.0            Sim          Sim            29.221  Prateleira
# 2         3.0            Sim          Sim            29.221  Prateleira
# 3         3.0            Sim          Sim            29.512  Prateleira
# 4         3.0            Sim          Sim            29.512  Prateleira
# ...       ...            ...          ...               ...         ...
# 46126     NaN            NaN          NaN               NaN         NaN
# 46127     NaN            NaN          NaN               NaN         NaN
# 46128     NaN            NaN          NaN               NaN         NaN
# 46129     NaN            NaN          NaN               NaN         NaN
# 46130     NaN            NaN          NaN               NaN         NaN
#
#        Qtde Desvio Picking local
# 0                     21.0    fd
# 1                     29.0    fd
# 2                     29.0    fd
# 3                      6.0    fd
# 4                      6.0    fd
# ...                    ...   ...
# 46126                  0.0   NaN
# 46127                  0.0   NaN
# 46128                  0.0   NaN
# 46129                  0.0   NaN
# 46130                  0.0   NaN
#
# [46131 rows x 29 columns]

# %%
teste.drop_duplicates(inplace = True)

# %%
teste.set_index('Ordem', inplace=True)

# %%
teste.sort_values(by='Qtde Venda Frac', ascending=False)
# Out:
#        Código                                Descrição Curva Frac Curva Cx  \
# Ordem
# 6783   801782  PEITORALGUIA CÃESGR PET NEON LARANJA-PP          C      NaN
# 8892    62670                SULFERBEL XPE FR C/ 100ML          C      NaN
# 2785   132371         BROMAZEPAM 6MG (B1)** C/ 30 COMP          C      NaN
# 6540     1470              PA PEQUENA AZUL PROMOCIONAL          C      NaN
# 8886   312751                SULFA+TRI SUSP (AM) 100ML          C      NaN
# ...       ...                                      ...        ...      ...
# 9417   316036  ZOLPIDEM 10MG C/30 CPR (B1)** TEUTO-GEN        NaN      NaN
# 9418    11211            ZOLPIDEM 10MG 10CP (B1)** GEN        NaN      NaN
# 9419    29909             ZOLPIDEM 10MG 10CP (B1)** NQ        NaN      NaN
# 9420    29910             ZOLPIDEM 10MG 20CP (B1)** NQ        NaN      NaN
# 9421   420655           ZOLPIDEM 10MG 20CPR (B1)**EURO        NaN      NaN
#
#       Curva Geral  Qtde Venda Frac  Qtde Venda Cx  Qtde Venda Geral  \
# Ordem
# 6783          NaN              0.0            NaN               NaN
# 8892          NaN              0.0            NaN               NaN
# 2785          NaN              0.0            NaN               NaN
# 6540          NaN              0.0            NaN               NaN
# 8886          NaN              0.0            NaN               NaN
# ...           ...              ...            ...               ...
# 9417          NaN              NaN            NaN               NaN
# 9418          NaN              NaN            NaN               NaN
# 9419          NaN              NaN            NaN               NaN
# 9420          NaN              NaN            NaN               NaN
# 9421          NaN              NaN            NaN               NaN
#
#        Dias Pedido Frac  Dias Pedido Cx  ...  Ender.Cx.Fechada  Estoque Frac  \
# Ordem                                    ...
# 6783                0.0             NaN  ...               NaN           1.0
# 8892                0.0             NaN  ...     016-013-01-01          30.0
# 2785                0.0             NaN  ...     018-008-01-01          20.0
# 6540                0.0             NaN  ...               NaN          65.0
# 8886                0.0             NaN  ...     016-028-01-02           0.0
# ...                 ...             ...  ...               ...           ...
# 9417                NaN             NaN  ...     018-004-01-02           0.0
# 9418                NaN             NaN  ...               NaN           0.0
# 9419                NaN             NaN  ...               NaN           0.0
# 9420                NaN             NaN  ...     018-006-01-01           0.0
# 9421                NaN             NaN  ...               NaN           0.0
#
#        Capacidade Frac  Embal.  Permite Frac.  Apanha Frac  Ender.Fracionado  \
# Ordem
# 6783               3.0    10.0            Não          Sim            16.146
# 8892              30.0    70.0            Não          Sim            25.147
# 2785              60.0    60.0            Não          Sim            10.548
# 6540               1.0    50.0            Não          Sim            17.476
# 8886               0.0    50.0            Sim          Não               NaN
# ...                ...     ...            ...          ...               ...
# 9417               0.0   100.0            Não          Não               NaN
# 9418               0.0    60.0            Não          Não               NaN
# 9419               0.0    60.0            Não          Não               NaN
# 9420             120.0    60.0            Não          Sim            10.207
# 9421               0.0    36.0            Não          Não               NaN
#
#              Tipo Qtde Desvio Picking        local
# Ordem
# 6783   Prateleira                 0.0          NaN
# 8892   Prateleira                 0.0       fech_a
# 2785   Prateleira                 0.0   controlado
# 6540   Prateleira                 0.0          NaN
# 8886          NaN                 0.0  antibiotico
# ...           ...                 ...          ...
# 9417          NaN                 NaN   controlado
# 9418          NaN                 NaN          NaN
# 9419          NaN                 NaN          NaN
# 9420   Prateleira                 NaN   controlado
# 9421          NaN                 NaN          NaN
#
# [9431 rows x 28 columns]

# %%
teste.to_excel('teste.xlsx')
