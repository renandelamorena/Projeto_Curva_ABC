# %%
import pandas as pd

situacao_final = pd.read_excel(r'C:\Users\estoque\Documents\estoque.renan\projetos\projeto_curva_abc\tratamento_curva_abc\dados_tratados/situacao_final.xlsx')
enderecos = situacao_final[['Ender.Cx.Fechada']].astype(str)

display(enderecos)

locais = pd.read_excel(r'C:\Users\estoque\Documents\estoque.renan\projetos\projeto_curva_abc\tratamento_curva_abc\datasets/local_apanha_cx.xlsx').astype(str)

display(locais)
# Out:
#      Ender.Cx.Fechada
# 0       016-037-01-01
# 1       016-043-01-02
# 2       016-035-01-02
# 3       014-032-02-01
# 4       015-033-01-01
# ...               ...
# 9370    018-001-01-02
# 9371    018-004-01-02
# 9372    018-001-01-01
# 9373              nan
# 9374    018-003-01-01
#
# [9375 rows x 1 columns]
#     Ender.Cx.Fechada       local
# 0      014-006-01-01      fech_a
# 1      014-006-01-02      fech_a
# 2      014-008-01-01      fech_a
# 3      014-008-01-02      fech_a
# 4      014-010-01-01      fech_a
# ..               ...         ...
# 478    018-006-01-02  controlado
# 479    018-007-01-01  controlado
# 480    018-007-01-02  controlado
# 481    018-008-01-01  controlado
# 482    018-008-01-02  controlado
#
# [483 rows x 2 columns]

# %%
enderecos_x_locais = pd.merge(enderecos, locais)
enderecos_x_locais
# Out:
#      Ender.Cx.Fechada     local
# 0       016-037-01-01    pallet
# 1       016-043-01-02    pallet
# 2       016-035-01-02    pallet
# 3       014-032-02-01  flowrack
# 4       015-033-01-01    fech_a
# ...               ...       ...
# 3136    018-036-01-01    outros
# 3137    018-032-01-01    outros
# 3138    018-032-00-01    outros
# 3139    018-021-00-01        fd
# 3140    018-040-01-01    outros
#
# [3141 rows x 2 columns]

# %%
total_enderecos_usados = enderecos.drop_duplicates()
total_enderecos_usados
# Out:
#      Ender.Cx.Fechada
# 0       016-037-01-01
# 1       016-043-01-02
# 2       016-035-01-02
# 3       014-032-02-01
# 4       015-033-01-01
# ...               ...
# 3358    014-025-03-01
# 3362    014-028-03-01
# 3365    014-029-03-01
# 3367    100-001-01-01
# 3370    010-010-03-01
#
# [475 rows x 1 columns]

# %%
item_com_end = ~(enderecos['Ender.Cx.Fechada'] == 'nan')

# %%
item_com_end
enderecos[item_com_end]
# Out:
#      Ender.Cx.Fechada
# 0       016-037-01-01
# 1       016-043-01-02
# 2       016-035-01-02
# 3       014-032-02-01
# 4       015-033-01-01
# ...               ...
# 9342    016-023-01-01
# 9370    018-001-01-02
# 9371    018-004-01-02
# 9372    018-001-01-01
# 9374    018-003-01-01
#
# [3199 rows x 1 columns]

# %%
situacao_final
# Out:
#       Ordem  Código                                Descrição Curva Frac  \
# 0         1  106011              NARIDRIN 12 HORAS FR C/30ML          A
# 1         2  231012                  EXPEC XAROPE FR C/120ML          A
# 2         3  101190                    EMSEXPECTOR XPE 120ML          A
# 3         4  101175                      INFRALAX C/ 15 COMP          A
# 4         5   10302                  LOSARTANA POT 50MG 30CP          A
# ...     ...     ...                                      ...        ...
# 9370   9371  421840     ZOLPIDEM  5MG (B1)** C/ 30 COMP SUBL        NaN
# 9371   9372  316036  ZOLPIDEM 10MG C/30 CPR (B1)** TEUTO-GEN        NaN
# 9372   9373   11211            ZOLPIDEM 10MG 10CP (B1)** GEN        NaN
# 9373   9374   29909             ZOLPIDEM 10MG 10CP (B1)** NQ        NaN
# 9374   9375  420655           ZOLPIDEM 10MG 20CPR (B1)**EURO        NaN
#
#      Curva Cx Curva Geral  Qtde Venda Frac  Qtde Venda Cx  Qtde Venda Geral  \
# 0           A           A         339771.0         7332.0         1072921.0
# 1           A           A         179981.0         5347.0          500717.0
# 2           A           A         205638.0         1432.0          291552.0
# 3           A           A          99249.0         1567.0          174453.0
# 4           A           A          35107.0         1623.0          171439.0
# ...       ...         ...              ...            ...               ...
# 9370      NaN         NaN              NaN            NaN               NaN
# 9371      NaN         NaN              NaN            NaN               NaN
# 9372      NaN         NaN              NaN            NaN               NaN
# 9373      NaN         NaN              NaN            NaN               NaN
# 9374      NaN         NaN              NaN            NaN               NaN
#
#       Dias Pedido Frac  ...  Estoque Armaz.  Ender.Cx.Fechada  Estoque Frac  \
# 0                285.0  ...          2469.0     016-037-01-01         261.0
# 1                259.0  ...          2335.0     016-043-01-02         230.0
# 2                261.0  ...           938.0     016-035-01-02         155.0
# 3                267.0  ...           499.0     014-032-02-01         267.0
# 4                178.0  ...             0.0     015-033-01-01           0.0
# ...                ...  ...             ...               ...           ...
# 9370               NaN  ...             0.0     018-001-01-02           0.0
# 9371               NaN  ...             0.0     018-004-01-02           0.0
# 9372               NaN  ...             0.0     018-001-01-01           0.0
# 9373               NaN  ...             0.0               NaN           0.0
# 9374               NaN  ...             0.0     018-003-01-01           0.0
#
#       Capacidade Frac  Embal.  Permite Frac.  Apanha Frac  Ender.Fracionado  \
# 0               200.0   100.0            Não          Sim            29.913
# 1               240.0    60.0            Não          Sim            18.015
# 2               240.0    60.0            Não          Sim            29.911
# 3               336.0    48.0            Não          Sim            25.064
# 4                 0.0    84.0            Não          Não               NaN
# ...               ...     ...            ...          ...               ...
# 9370              0.0    96.0            Não          Não               NaN
# 9371              0.0   100.0            Não          Não               NaN
# 9372            120.0    60.0            Não          Sim            11.103
# 9373              0.0    60.0            Não          Não               NaN
# 9374             36.0    36.0            Não          Sim            11.144
#
#             Tipo Qtde Desvio Picking
# 0     Ponta De G              3948.0
# 1       Flowrack              3007.0
# 2     Ponta De G              5621.0
# 3       Flowrack              2853.0
# 4            NaN               124.0
# ...          ...                 ...
# 9370         NaN                 NaN
# 9371         NaN                 NaN
# 9372  Prateleira                 NaN
# 9373         NaN                 NaN
# 9374  Prateleira                 NaN
#
# [9375 rows x 28 columns]

# %%
teste = pd.merge(situacao_final, enderecos_x_locais, how = 'left')

# %%
teste
# Out:
#        Ordem  Código                       Descrição Curva Frac Curva Cx  \
# 0          1  106011     NARIDRIN 12 HORAS FR C/30ML          A        A
# 1          2  231012         EXPEC XAROPE FR C/120ML          A        A
# 2          3  101190           EMSEXPECTOR XPE 120ML          A        A
# 3          4  101175             INFRALAX C/ 15 COMP          A        A
# 4          5   10302         LOSARTANA POT 50MG 30CP          A        A
# ...      ...     ...                             ...        ...      ...
# 44398   9375  420655  ZOLPIDEM 10MG 20CPR (B1)**EURO        NaN      NaN
# 44399   9375  420655  ZOLPIDEM 10MG 20CPR (B1)**EURO        NaN      NaN
# 44400   9375  420655  ZOLPIDEM 10MG 20CPR (B1)**EURO        NaN      NaN
# 44401   9375  420655  ZOLPIDEM 10MG 20CPR (B1)**EURO        NaN      NaN
# 44402   9375  420655  ZOLPIDEM 10MG 20CPR (B1)**EURO        NaN      NaN
#
#       Curva Geral  Qtde Venda Frac  Qtde Venda Cx  Qtde Venda Geral  \
# 0               A         339771.0         7332.0         1072921.0
# 1               A         179981.0         5347.0          500717.0
# 2               A         205638.0         1432.0          291552.0
# 3               A          99249.0         1567.0          174453.0
# 4               A          35107.0         1623.0          171439.0
# ...           ...              ...            ...               ...
# 44398         NaN              NaN            NaN               NaN
# 44399         NaN              NaN            NaN               NaN
# 44400         NaN              NaN            NaN               NaN
# 44401         NaN              NaN            NaN               NaN
# 44402         NaN              NaN            NaN               NaN
#
#        Dias Pedido Frac  ...  Ender.Cx.Fechada  Estoque Frac  Capacidade Frac  \
# 0                 285.0  ...     016-037-01-01         261.0            200.0
# 1                 259.0  ...     016-043-01-02         230.0            240.0
# 2                 261.0  ...     016-035-01-02         155.0            240.0
# 3                 267.0  ...     014-032-02-01         267.0            336.0
# 4                 178.0  ...     015-033-01-01           0.0              0.0
# ...                 ...  ...               ...           ...              ...
# 44398               NaN  ...     018-003-01-01           0.0             36.0
# 44399               NaN  ...     018-003-01-01           0.0             36.0
# 44400               NaN  ...     018-003-01-01           0.0             36.0
# 44401               NaN  ...     018-003-01-01           0.0             36.0
# 44402               NaN  ...     018-003-01-01           0.0             36.0
#
#        Embal.  Permite Frac.  Apanha Frac  Ender.Fracionado        Tipo  \
# 0       100.0            Não          Sim            29.913  Ponta De G
# 1        60.0            Não          Sim            18.015    Flowrack
# 2        60.0            Não          Sim            29.911  Ponta De G
# 3        48.0            Não          Sim            25.064    Flowrack
# 4        84.0            Não          Não               NaN         NaN
# ...       ...            ...          ...               ...         ...
# 44398    36.0            Não          Sim            11.144  Prateleira
# 44399    36.0            Não          Sim            11.144  Prateleira
# 44400    36.0            Não          Sim            11.144  Prateleira
# 44401    36.0            Não          Sim            11.144  Prateleira
# 44402    36.0            Não          Sim            11.144  Prateleira
#
#        Qtde Desvio Picking       local
# 0                   3948.0      pallet
# 1                   3007.0      pallet
# 2                   5621.0      pallet
# 3                   2853.0    flowrack
# 4                    124.0      fech_a
# ...                    ...         ...
# 44398                  NaN  controlado
# 44399                  NaN  controlado
# 44400                  NaN  controlado
# 44401                  NaN  controlado
# 44402                  NaN  controlado
#
# [44403 rows x 29 columns]

# %%
teste.drop_duplicates(inplace = True)

# %%
teste
# Out:
#        Ordem  Código                                Descrição Curva Frac  \
# 0          1  106011              NARIDRIN 12 HORAS FR C/30ML          A
# 1          2  231012                  EXPEC XAROPE FR C/120ML          A
# 2          3  101190                    EMSEXPECTOR XPE 120ML          A
# 3          4  101175                      INFRALAX C/ 15 COMP          A
# 4          5   10302                  LOSARTANA POT 50MG 30CP          A
# ...      ...     ...                                      ...        ...
# 44307   9371  421840     ZOLPIDEM  5MG (B1)** C/ 30 COMP SUBL        NaN
# 44336   9372  316036  ZOLPIDEM 10MG C/30 CPR (B1)** TEUTO-GEN        NaN
# 44353   9373   11211            ZOLPIDEM 10MG 10CP (B1)** GEN        NaN
# 44381   9374   29909             ZOLPIDEM 10MG 10CP (B1)** NQ        NaN
# 44382   9375  420655           ZOLPIDEM 10MG 20CPR (B1)**EURO        NaN
#
#       Curva Cx Curva Geral  Qtde Venda Frac  Qtde Venda Cx  Qtde Venda Geral  \
# 0            A           A         339771.0         7332.0         1072921.0
# 1            A           A         179981.0         5347.0          500717.0
# 2            A           A         205638.0         1432.0          291552.0
# 3            A           A          99249.0         1567.0          174453.0
# 4            A           A          35107.0         1623.0          171439.0
# ...        ...         ...              ...            ...               ...
# 44307      NaN         NaN              NaN            NaN               NaN
# 44336      NaN         NaN              NaN            NaN               NaN
# 44353      NaN         NaN              NaN            NaN               NaN
# 44381      NaN         NaN              NaN            NaN               NaN
# 44382      NaN         NaN              NaN            NaN               NaN
#
#        Dias Pedido Frac  ...  Ender.Cx.Fechada  Estoque Frac  Capacidade Frac  \
# 0                 285.0  ...     016-037-01-01         261.0            200.0
# 1                 259.0  ...     016-043-01-02         230.0            240.0
# 2                 261.0  ...     016-035-01-02         155.0            240.0
# 3                 267.0  ...     014-032-02-01         267.0            336.0
# 4                 178.0  ...     015-033-01-01           0.0              0.0
# ...                 ...  ...               ...           ...              ...
# 44307               NaN  ...     018-001-01-02           0.0              0.0
# 44336               NaN  ...     018-004-01-02           0.0              0.0
# 44353               NaN  ...     018-001-01-01           0.0            120.0
# 44381               NaN  ...               NaN           0.0              0.0
# 44382               NaN  ...     018-003-01-01           0.0             36.0
#
#        Embal.  Permite Frac.  Apanha Frac  Ender.Fracionado        Tipo  \
# 0       100.0            Não          Sim            29.913  Ponta De G
# 1        60.0            Não          Sim            18.015    Flowrack
# 2        60.0            Não          Sim            29.911  Ponta De G
# 3        48.0            Não          Sim            25.064    Flowrack
# 4        84.0            Não          Não               NaN         NaN
# ...       ...            ...          ...               ...         ...
# 44307    96.0            Não          Não               NaN         NaN
# 44336   100.0            Não          Não               NaN         NaN
# 44353    60.0            Não          Sim            11.103  Prateleira
# 44381    60.0            Não          Não               NaN         NaN
# 44382    36.0            Não          Sim            11.144  Prateleira
#
#        Qtde Desvio Picking       local
# 0                   3948.0      pallet
# 1                   3007.0      pallet
# 2                   5621.0      pallet
# 3                   2853.0    flowrack
# 4                    124.0      fech_a
# ...                    ...         ...
# 44307                  NaN  controlado
# 44336                  NaN  controlado
# 44353                  NaN  controlado
# 44381                  NaN         NaN
# 44382                  NaN  controlado
#
# [9375 rows x 29 columns]

# %%
teste.to_excel('teste.xlsx')
