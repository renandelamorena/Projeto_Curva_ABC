# %%
import pandas as pd
import plotly.graph_objects as go
import plotly

pd.set_option('display.max_columns', None)

situacao_final = pd.read_excel('data/tratamento_curva_abc/dados_tratados/situacao_final.xlsx').set_index('Ordem')
mapa_flowrack = pd.read_excel('mapa_estoque/mapa_flowrack_orientacao.xlsx', sheet_name=None)

# %%
def refatorar_indece(df, nome_index):
    
    qnt_linha = df.shape[0] + 1

    index = [i for i in range(1, qnt_linha)]

    df.set_index(pd.Index(index), inplace=True)

    df.index.name = nome_index
    
    return df

# %%
situacao_final.loc[[1]]
# Out:
#        Código                    Descrição Curva Frac Curva Cx Curva Geral  \
# Ordem
# 1      106011  NARIDRIN 12 HORAS FR C/30ML          A        A           A
#
#        Qtde Venda Frac  Qtde Venda Cx  Qtde Venda Geral  Dias Pedido Frac  \
# Ordem
# 1              64450.0         1026.0          167050.0              62.0
#
#        Dias Pedido Cx  Dias Pedido Geral  Ativ.Ressupr.Frac  Ativ.Ressupr.Cx  \
# Ordem
# 1                60.0               63.0              392.0             37.0
#
#        Ativ.Ressupr.Geral  Média por dia frac  Média por dia cx  \
# Ordem
# 1                   392.0           1039.5161              17.1
#
#        Média por dia geral  Estoque Armaz. Ender.Cx.Fechada Estoque Cx  \
# Ordem
# 1                2651.5873            4233    016-037-01-02         70
#
#        Capacidade Cx  Embal.  Estoque Frac  Capacidade Frac Permite Frac.  \
# Ordem
# 1                 20     100           283              300           Não
#
# ...

# %%
mapa_flowrack['10']
# Out:
#     10.10   10.20   10.30   10.40   10.50   10.60   10.70   10.80
# 0  10.011  10.021  10.031  10.041  10.051  10.061  10.071  10.081
# 1  10.012  10.022  10.032  10.042  10.052  10.062  10.072  10.082
# 2  10.013  10.023  10.033  10.043  10.053  10.063  10.073  10.083
# 3  10.014  10.024  10.034  10.044  10.054  10.064  10.074  10.084
# 4  10.015  10.025  10.035  10.045  10.055  10.065  10.075  10.085
# 5  10.016  10.026  10.036  10.046  10.056  10.066  10.076  10.086
