# %%
import pandas as pd

pd.read_excel('dados_tratados/curva_abc_geral.xlsx')
# Out:
#       Unnamed: 0  Cód.Produto                    Descrição Curva Geral  \
# 0              0       106011  NARIDRIN 12 HORAS FR C/30ML           A
# 1              1       231012      EXPEC XAROPE FR C/120ML           A
# 2              2       101190        EMSEXPECTOR XPE 120ML           A
# 3              3       101175          INFRALAX C/ 15 COMP           A
# 4              4       102138           INFRALAX C/30 COMP           A
# ...          ...          ...                          ...         ...
# 8940        8940       130073                          NaN         NaN
# 8941        8941       421840                          NaN         NaN
# 8942        8942       316036                          NaN         NaN
# 8943        8943        11211                          NaN         NaN
# 8944        8944        29909                          NaN         NaN
#
#       Qtde Venda Geral  Dias Pedido Geral  Média por dia Geral  Capacid.Chão  \
# ...

# %%
curva_geral.Curva.value_counts()
# Out:
# C    1019
# B     612
# A     407
# Name: Curva, dtype: int64

# %%
curva_geral.Curva.value_counts(normalize = True)
# Out:
# C    0.500000
# B    0.300294
# A    0.199706
# Name: Curva, dtype: float64

# %%
curva_geral.Curva.value_counts(normalize = True) * 100
# Out:
# C    50.000000
# B    30.029441
# A    19.970559
# Name: Curva, dtype: float64

# %%
frequencia = curva_geral.Curva.value_counts()

# %%
percentual = curva_geral.Curva.value_counts(normalize = True) * 100

# %%
dist_freq_curva = pd.DataFrame({'Frequência' : frequencia, 'Percentual (%)' : percentual})

# %%
dist_freq_curva
# Out:
#    Frequência  Percentual (%)
# C        1019       50.000000
# B         612       30.029441
# A         407       19.970559

# %%
dist_freq_curva.rename_axis('Curva', axis = 'columns', inplace = True)

# %%
dist_freq_curva
# Out:
# Curva  Frequência  Percentual (%)
# C            1019       50.000000
# B             612       30.029441
# A             407       19.970559
