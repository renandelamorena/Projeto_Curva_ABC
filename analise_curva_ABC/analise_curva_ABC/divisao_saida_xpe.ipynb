# %% [markdown]
# # Divisão de Saída

# %% [markdown]
# ## Import

# %%
import pandas as pd
pd.set_option('display.max_columns', None)

import math as mt

# %% [markdown]
# ## Func

# %%
def refatorar_indece(df, nome_index):
    
    qnt_linha = df.shape[0] + 1

    index = [i for i in range(1, qnt_linha)]

    df.set_index(pd.Index(index), inplace=True)

    df.index.name = nome_index
    
    return df

# %% [markdown]
# ## Xarope

# %%
curva_frac = pd.read_excel('dados_tratados/curva_abc_frac.xlsx')
curva_frac.set_index('Ordem', inplace = True)

# %%
curva_frac
# Out:
#        Código Curva Frac  Qtde Venda Frac  Dias Pedido Frac  \
# Ordem
# 1      106011          A         358262.0             285.0
# 2      101190          A         210821.0             249.0
# 3      231012          A         202491.0             255.0
# 4      102133          A         113290.0             279.0
# 5      102011          A         111651.0             283.0
# ...       ...        ...              ...               ...
# 9275   421840        NaN              NaN               NaN
# 9276   316036        NaN              NaN               NaN
# 9277    11211        NaN              NaN               NaN
# 9278    29909        NaN              NaN               NaN
# 9279   420655        NaN              NaN               NaN
#
#        Média por dia frac  Ativ.Ressupr.Frac  Qtde Desvio Picking  \
# Ordem
# 1               1257.0596             1354.0               4501.0
# 2                846.6707             1109.0               7197.0
# 3                794.0824             1010.0               3382.0
# 4                406.0573              752.0               6424.0
# 5                394.5265              739.0               6183.0
# ...                   ...                ...                  ...
# 9275                  NaN                NaN                  NaN
# 9276                  NaN                NaN                  NaN
# 9277                  NaN                NaN                  NaN
# 9278                  NaN                NaN                  NaN
# 9279                  NaN                NaN                  NaN
#
#        Capacid.Apan.Frac                                Descrição  \
# Ordem
# 1                  300.0              NARIDRIN 12 HORAS FR C/30ML
# 2                  240.0                    EMSEXPECTOR XPE 120ML
# 3                  240.0                  EXPEC XAROPE FR C/120ML
# 4                  336.0     ALLEXOFEDRIN ( D) 60+120MG C/ 10COMP
# 5                  300.0                          CYSTEX C/ 24DRG
# ...                  ...                                      ...
# 9275                 NaN     ZOLPIDEM  5MG (B1)** C/ 30 COMP SUBL
# 9276                 NaN  ZOLPIDEM 10MG C/30 CPR (B1)** TEUTO-GEN
# 9277                 NaN            ZOLPIDEM 10MG 10CP (B1)** GEN
# 9278                 NaN             ZOLPIDEM 10MG 10CP (B1)** NQ
# 9279                 NaN           ZOLPIDEM 10MG 20CPR (B1)**EURO
#
#        Estoque Armaz. Apanha Cx Permite Frac. Ender.Cx.Fechada  Embal.  \
# Ordem
# 1              2951.0       Sim           Não    016-037-01-01   100.0
# 2              1120.0       Sim           Não    016-035-01-02    60.0
# 3              2760.0       Sim           Não    016-043-01-02    60.0
# 4               779.0       Sim           Não    014-040-02-02    48.0
# 5               262.0       Sim           Não    014-022-02-02   100.0
# ...               ...       ...           ...              ...     ...
# 9275              0.0       Sim           Não    018-001-01-02    96.0
# 9276              0.0       Sim           Não    018-004-01-02   100.0
# 9277              0.0       Sim           Não    018-001-01-01    60.0
# 9278              0.0       Não           Não              NaN    60.0
# 9279              0.0       Sim           Não    018-003-01-01    36.0
#
#        Capacidade Cx Estoque Cx Apanha Frac  Ender.Fracionado        Tipo  \
# Ordem
# 1               15.0         87         Sim            18.903  Ponta De G
# 2                5.0         26         Sim            29.075    Flowrack
# 3                5.0         20         Sim            29.913  Ponta De G
# 4               36.0         27         Sim            29.033    Flowrack
# 5               16.0         11         Sim            21.084    Flowrack
# ...              ...        ...         ...               ...         ...
# 9275             1.0          0         Não               NaN         NaN
# 9276             2.0          0         Não               NaN         NaN
# 9277             2.0          0         Sim            11.103  Prateleira
# 9278             0.0          0         Não               NaN         NaN
# 9279             4.0          0         Sim            11.144  Prateleira
#
#        Capacidade Frac  Estoque Frac
# Ordem
# 1                300.0         342.0
# 2                240.0         217.0
# 3                240.0         271.0
# 4                336.0         262.0
# 5                300.0         368.0
# ...                ...           ...
# 9275               0.0           0.0
# 9276               0.0           0.0
# 9277             120.0           0.0
# 9278               0.0           0.0
# 9279              36.0           0.0
#
# [9279 rows x 21 columns]

# %%
selecao = (curva_frac['Descrição'].str.contains('xpe|susp|sol|elixir', case=False)) & \
          (~curva_frac['Descrição'].str.contains('REPOSIT|NEOLEFRIN|NORIFERUM|MAISOL|MERTHICORT|FRASCO|GOTAS|oft|spr', case=False)) & \
          (curva_frac['Curva Frac'] == 'A') & \
          (curva_frac['Embal.'] == 60.0)

xpe = curva_frac[selecao]
xpe
# Out:
#        Código Curva Frac  Qtde Venda Frac  Dias Pedido Frac  \
# Ordem
# 2      101190          A         210821.0             249.0
# 3      231012          A         202491.0             255.0
# 10     101066          A          74443.0             237.0
# 13      10583          A          65478.0             192.0
# 17     102322          A          52953.0              62.0
# 25     231262          A          39998.0             187.0
# 28      10579          A          39224.0             150.0
# 37      10198          A          31656.0             168.0
# 39      10220          A          30624.0             188.0
# 51      10160          A          25839.0             173.0
# 57     231048          A          23483.0             139.0
# 67     102379          A          21529.0             207.0
# 87      10066          A          15778.0             209.0
# 98      10191          A          14011.0             139.0
# 100    101318          A          13781.0             210.0
# 106    232484          A          12627.0             105.0
# 113    231933          A          11543.0             191.0
# 120    101185          A          10788.0             221.0
# 127     10131          A          10033.0             102.0
# 130    101016          A           9544.0             193.0
# 143    101072          A           8195.0             212.0
# 146    231225          A           8119.0              92.0
# 161    101015          A           7294.0             178.0
# 168     10190          A           6867.0             136.0
# 169     14265          A           6706.0             153.0
# 171     14265          A           6706.0             153.0
# 201    102245          A           5399.0             233.0
# 203    102383          A           5278.0             250.0
# 243    101163          A           4413.0             129.0
# 280     10168          A           3836.0              91.0
# 289    231936          A           3575.0             181.0
# 297     11118          A           3475.0               2.0
# 332     12511          A           2983.0              54.0
# 348    101364          A           2743.0             157.0
# 364     12515          A           2505.0              46.0
# 372     10067          A           2466.0             135.0
# 399     14344          A           2312.0              74.0
# 446     12752          A           1914.0              98.0
# 452    102467          A           1891.0             116.0
# 461    102246          A           1851.0             204.0
# 509     12523          A           1624.0              57.0
# 515     14571          A           1594.0             128.0
# 522     10745          A           1568.0             117.0
# 563     10197          A           1355.0              71.0
# 612     14340          A           1168.0              39.0
# 618     10169          A           1141.0              54.0
# 651    110287          A           1034.0              92.0
#
#        Média por dia frac  Ativ.Ressupr.Frac  Qtde Desvio Picking  \
# Ordem
# 2                846.6707             1109.0               7197.0
# 3                794.0824             1010.0               3382.0
# 10               314.1055              576.0               2572.0
# 13               341.0313              403.0               1208.0
# 17               854.0806              304.0               4979.0
# 25               213.8930              243.0               2058.0
# 28               261.4933              209.0                529.0
# 37               188.4286              155.0                724.0
# 39               162.8936              242.0                625.0
# 51               149.3584              211.0                864.0
# 57               168.9424              192.0               1446.0
# 67               104.0048              173.0                393.0
# 87                75.4928              140.0                313.0
# 98               100.7986              168.0                736.0
# 100               65.6238               92.0                869.0
# 106              120.2571              273.0               1731.0
# 113               60.4346              161.0               1048.0
# 120               48.8145              136.0                287.0
# 127               98.3627               72.0                264.0
# 130               49.4508               62.0                567.0
# 143               38.6557               60.0                575.0
# 146               88.2500               54.0                426.0
# 161               40.9775               81.0                426.0
# 168               50.4926               74.0                272.0
# 169               43.8301               74.0                476.0
# 171               43.8301               74.0                476.0
# 201               23.1717               83.0                356.0
# 203               21.1120               67.0                488.0
# 243               34.2093               42.0                251.0
# 280               42.1538               55.0                164.0
# 289               19.7514               52.0                243.0
# 297             1737.5000               10.0                186.0
# 332               55.2407               48.0                185.0
# 348               17.4713               24.0                234.0
# 364               54.4565               30.0                 54.0
# 372               18.2667               20.0                139.0
# 399               31.2432               12.0                134.0
# 446               19.5306               72.0                 94.0
# 452               16.3017              113.0                205.0
# 461                9.0735               15.0                147.0
# 509               28.4912                8.0                 71.0
# 515               12.4531               20.0                167.0
# 522               13.4017               97.0                128.0
# 563               19.0845               14.0                 64.0
# 612               29.9487               12.0                146.0
# 618               21.1296               10.0                113.0
# 651               11.2391               10.0                102.0
#
#        Capacid.Apan.Frac                                Descrição  \
# Ordem
# 2                  240.0                    EMSEXPECTOR XPE 120ML
# 3                  240.0                  EXPEC XAROPE FR C/120ML
# 10                 150.0                       CELERGIN XPE 120ML
# 13                 240.0              DIPIRONA SOD SOL ORAL 100ML
# 17                 240.0                CLOPE 3,54MG/ML XPE 120ML
# 25                 240.0               EXPEC-TAMIN SOL ORAL 120ML
# 28                 240.0         ACETILCISTEINA 20MG/ML XPE 120ML
# 37                 240.0                     DEXCL+BETA XPE 120ML
# 39                 240.0              DEXCLORFENIRAMINA XPE 120ML
# 51                 240.0                DEXAMETASONA ELIXIR 120ML
# 57                 180.0                         CELERG XPE 120ML
# 67                 100.0            POLAPIC 0,4MG/ML SOL OR 120ML
# 87                 180.0              CARBOCISTEINA XPE AD  100ML
# 98                 120.0                   AMBROXOL XPE INF 120ML
# 100                360.0             BISURAN XPE AD 8MG/5ML 120ML
# 106                180.0  EXPEC HEDRA 7MG/ML SOL ORAL C/ 100 ML-L
# 113                240.0       LACTULIV 667MG/ML SOL AMEIXA 120ML
# 120                180.0           HIXILERG 2MG/ML SOL ORAL 120ML
# 127                240.0              LORATADINA 1MG/ML XPE 100ML
# 130                300.0              EXPECTUSS ADULTO FR C/100ML
# 143                240.0            BISURAN XPE INF 4MG/5ML 120ML
# 146                360.0       IBUFLEX 100MG/ML SUSP ORAL C/ 30ML
# 161                180.0            EXPECTUSS INFANTIL FR C/100ML
# 168                240.0                    AMBROXOL XPE AD 120ML
# 169                180.0         ACETILCISTEINA 40MG/ML XPE 120ML
# 171                180.0         ACETILCISTEINA 40MG/ML XPE 120ML
# 201                120.0      NORMOLAX AMEIXA  667MG/ML SOL 120ML
# 203                180.0              COMPLEXO B12 XPE FR C/120ML
# 243                240.0         FLUITEINA XPE INF 20MG//ML 120ML
# 280                120.0         CEFALEXINA SUSP 250MG (AM) 100ML
# 289                120.0   LACTULIV 667MG/ML SOL SAL.FRUTAS 120ML
# 297                  0.0     CLOPERASTINA XPE 3,54 MG/ML C/120 ML
# 332                 90.0         ACETILCISTEINA 20MG/ML XPE 120ML
# 348                240.0           FLUITEINA XPE AD 40MG/ML 120ML
# 364                240.0              DIPIRONA SOD SOL ORAL 100ML
# 372                240.0              CARBOCISTEINA XPE INF 100ML
# 399                240.0              DIPIRONA SOD SOL ORAL 100ML
# 446                240.0               HIDROXIZINA SOL ORAL 120ML
# 452                 60.0          BRONDELIX 7MG/ML XPE FR C/100ML
# 461                120.0    NORMOLAX SAL FRUTAS 667MG/ML SOL120ML
# 509                420.0                     DEXCL+BETA XPE 120ML
# 515                180.0               HIDROXIZINA SOL ORAL 120ML
# 522                 20.0                  BROMEXINA XPE INF 120ML
# 563                180.0                BETAMETASONA ELIXIR 120ML
# 612                180.0         ACETILCISTEINA 20MG/ML XPE 120ML
# 618                 60.0                SULFA+TRI SUSP (AM) 100ML
# 651                240.0               HISTAMIN XPE 2MG/5ML 100ML
#
#        Estoque Armaz. Apanha Cx Permite Frac. Ender.Cx.Fechada  Embal.  \
# Ordem
# 2              1120.0       Sim           Não    016-035-01-02    60.0
# 3              2760.0       Sim           Não    016-043-01-02    60.0
# 10              230.0       Sim           Não    014-032-01-02    60.0
# 13              150.0       Sim           Não    016-033-01-02    60.0
# 17                0.0       Sim           Não    016-043-01-01    60.0
# 25              330.0       Sim           Não    014-024-01-02    60.0
# 28               87.0       Sim           Não    016-039-01-02    60.0
# 37               75.0       Sim           Não    014-032-01-01    60.0
# 39               22.0       Sim           Não    014-028-01-01    60.0
# 51               54.0       Sim           Não    014-020-01-02    60.0
# 57              200.0       Sim           Não    014-036-01-02    60.0
# 67              164.0       Sim           Não    015-015-01-02    60.0
# 87               47.0       Sim           Não    016-013-01-02    60.0
# 98               95.0       Sim           Não    010-032-01-01    60.0
# 100              24.0       Sim           Não    016-027-01-02    60.0
# 106             317.0       Sim           Não    010-034-01-02    60.0
# 113              69.0       Sim           Não    014-018-01-01    60.0
# 120              46.0       Sim           Não    014-022-01-02    60.0
# 127              18.0       Sim           Não    014-020-01-01    60.0
# 130              36.0       Sim           Não    014-040-01-02    60.0
# 143              15.0       Sim           Não    016-003-01-01    60.0
# 146              82.0       Sim           Não    014-006-01-02    60.0
# 161              36.0       Sim           Não    010-030-01-01    60.0
# 168              48.0       Sim           Sim    010-024-01-01    60.0
# 169               0.0       Sim           Não    015-007-01-02    60.0
# 171               0.0       Sim           Não    015-007-01-02    60.0
# 201              14.0       Sim           Não    014-024-01-01    60.0
# 203              13.0       Sim           Não    014-034-01-01    60.0
# 243              10.0       Sim           Não    014-010-01-02    60.0
# 280               5.0       Sim           Não    016-030-01-01    60.0
# 289              14.0       Sim           Não    016-021-01-01    60.0
# 297               0.0       Sim           Não    016-012-01-01    60.0
# 332               0.0       Sim           Não    016-007-01-01    60.0
# 348               9.0       Sim           Não    014-034-01-01    60.0
# 364               2.0       Sim           Não    014-018-01-01    60.0
# 372               0.0       Sim           Não    015-011-01-01    60.0
# 399              10.0       Sim           Não    014-026-01-01    60.0
# 446               6.0       Sim           Sim    016-008-01-02    60.0
# 452               0.0       Sim           Não    015-017-01-01    60.0
# 461               3.0       Sim           Não    015-027-01-01    60.0
# 509               0.0       Sim           Não    014-014-01-02    60.0
# 515               1.0       Sim           Não    014-016-01-02    60.0
# 522               1.0       Sim           Sim    010-028-01-02    60.0
# 563               0.0       Sim           Não    014-036-01-01    60.0
# 612              12.0       Sim           Não    010-030-01-02    60.0
# 618               0.0       Sim           Não    016-024-01-01    60.0
# 651               0.0       Sim           Não    016-021-01-01    60.0
#
#        Capacidade Cx  Estoque Cx Apanha Frac  Ender.Fracionado        Tipo  \
# Ordem
# 2                5.0          26         Sim            29.075    Flowrack
# 3                5.0          20         Sim            29.913  Ponta De G
# 10              15.0          14         Sim            29.085    Flowrack
# 13               5.0           7         Sim            29.911  Ponta De G
# 17              15.0          22         Sim            17.045    Flowrack
# 25              12.0          12         Sim            26.065    Flowrack
# 28               5.0           3         Sim            18.056    Flowrack
# 37              13.0          11         Sim            18.085    Flowrack
# 39              12.0          12         Sim            24.075    Flowrack
# 51              17.0          15         Sim            26.085    Flowrack
# 57              15.0          12         Sim            26.055    Flowrack
# 67              12.0          10         Sim            19.065    Flowrack
# 87              10.0           8         Sim            18.045    Flowrack
# 98              10.0          10         Sim            26.903  Ponta De G
# 100              5.0           5         Sim            23.055    Flowrack
# 106             10.0          10         Sim            21.055    Flowrack
# 113              5.0           5         Sim            26.076    Flowrack
# 120              5.0           4         Sim            21.075    Flowrack
# 127             12.0          10         Sim            21.056    Flowrack
# 130              6.0           5         Sim            23.035    Flowrack
# 143             12.0          10         Sim            26.036    Flowrack
# 146             15.0          11         Sim            27.025    Flowrack
# 161              5.0           5         Sim            29.015    Flowrack
# 168              3.0  2 (+48 fr)         Sim            18.035    Flowrack
# 169              8.0           0         Sim            25.086    Flowrack
# 171              8.0           0         Sim            25.086    Flowrack
# 201              3.0           3         Sim            29.905  Ponta De G
# 203              5.0           4         Sim            27.065    Flowrack
# 243              3.0           3         Sim            22.066    Flowrack
# 280              5.0           4         Sim            29.025    Flowrack
# 289              3.0           3         Sim            24.076    Flowrack
# 297              1.0           0         Não               NaN         NaN
# 332              3.0           3         Sim            29.056    Flowrack
# 348              5.0           5         Sim            24.026    Flowrack
# 364              4.0           5         Sim            18.026    Flowrack
# 372             15.0          11         Sim            26.075    Flowrack
# 399              5.0           5         Sim            24.036    Flowrack
# 446              2.0   1 (+8 fr)         Sim            27.036    Flowrack
# 452             10.0  3 (+47 fr)         Sim            19.056    Flowrack
# 461              3.0           3         Sim            20.076    Flowrack
# 509              5.0           0         Sim            18.014    Flowrack
# 515              3.0           3         Sim            23.065    Flowrack
# 522              3.0  2 (+28 fr)         Sim            20.128  Prateleira
# 563              4.0           0         Sim            28.075    Flowrack
# 612              3.0           3         Sim            21.035    Flowrack
# 618              3.0           0         Sim            22.224  Prateleira
# 651              6.0           0         Sim            22.026    Flowrack
#
#        Capacidade Frac  Estoque Frac
# Ordem
# 2                240.0         217.0
# 3                240.0         271.0
# 10               150.0         164.0
# 13               240.0         179.0
# 17               240.0         202.0
# 25               240.0         192.0
# 28               240.0         274.0
# 37               240.0         194.0
# 39               240.0         283.0
# 51               240.0         223.0
# 57               180.0         220.0
# 67               100.0         120.0
# 87               180.0         212.0
# 98               120.0         142.0
# 100              360.0         332.0
# 106              180.0         196.0
# 113              240.0         188.0
# 120              180.0         135.0
# 127              240.0         289.0
# 130              300.0         277.0
# 143              240.0         266.0
# 146              360.0         349.0
# 161              180.0         194.0
# 168              240.0         240.0
# 169              180.0           0.0
# 171              180.0           0.0
# 201              120.0         130.0
# 203              180.0         158.0
# 243              240.0         268.0
# 280              120.0         115.0
# 289              120.0         107.0
# 297                0.0           0.0
# 332               90.0          78.0
# 348              240.0         207.0
# 364              240.0         265.0
# 372              240.0         203.0
# 399              240.0         218.0
# 446              240.0         202.0
# 452               60.0          60.0
# 461              120.0          46.0
# 509              420.0          14.0
# 515              180.0         151.0
# 522               20.0          20.0
# 563              180.0         137.0
# 612              115.0         224.0
# 618               60.0           0.0
# 651              240.0          46.0

# %%
refatorar_indece(xpe, 'Ordem')

cod_xpe = xpe['Código']

desc_xpe = xpe['Descrição']

saida_xpe = xpe['Qtde Venda Frac']

# %%
qnt_enderecos_modulo_xpe = 8
print((f'Total de endereços de xarope por modulo: {qnt_enderecos_modulo_xpe}'))

modulos = 6
print(f'Total de modulos: {modulos}')

total_enderecos_xpe = qnt_enderecos_modulo_xpe * modulos
print(f'Total de endereços xarope: {total_enderecos_xpe}')

total_curva_a_xpe = xpe.shape[0]
print(f'Total de xaropes: {total_curva_a_xpe}')

qnt_itens_modulo_xpe = mt.ceil(total_curva_a_xpe / modulos)
print(f'Total de xaropes por modulo: {qnt_itens_modulo_xpe}')

ordem_modulo_xpe = [x for x in range(1, qnt_enderecos_modulo_xpe + 1)]
ordem_modulo_xpe
# Out:
# Total de endereços de xarope por modulo: 8
# Total de modulos: 6
# Total de endereços xarope: 48
# Total de xaropes: 47
# Total de xaropes por modulo: 8
# [1, 2, 3, 4, 5, 6, 7, 8]

# %%
step = 6

# %%
primeiro_m = [x for x in range(1, qnt_enderecos_modulo_xpe * step, step)]

segundo_m = [x for x in range(3, qnt_enderecos_modulo_xpe * step, step)]

terceiro_m = [x for x in range(5, qnt_enderecos_modulo_xpe * step, step)]

quarto_m = [x for x in range(6, qnt_enderecos_modulo_xpe * step + 1, step)]

quinto_m = [x for x in range(4, qnt_enderecos_modulo_xpe * step, step)]

sexto_m = [x for x in range(2, qnt_enderecos_modulo_xpe * step, step)]

# %%
modulos = [{'29_28' : primeiro_m},
           {'27_26' : segundo_m},
           {'25_24' : terceiro_m},
           {'23_22' : quarto_m},
           {'21_20' : quinto_m},
           {'19_18' : sexto_m},
          ]
modulos
# Out:
# [{'29_28': [1, 7, 13, 19, 25, 31, 37, 43]},
#  {'27_26': [3, 9, 15, 21, 27, 33, 39, 45]},
#  {'25_24': [5, 11, 17, 23, 29, 35, 41, 47]},
#  {'23_22': [6, 12, 18, 24, 30, 36, 42, 48]},
#  {'21_20': [4, 10, 16, 22, 28, 34, 40, 46]},
#  {'19_18': [2, 8, 14, 20, 26, 32, 38, 44]}]

# %%
# Criar um DataFrame vazio
divisao = pd.DataFrame()

# Iterar sobre os dicionários da lista
for d in modulos:
    # Iterar sobre as chaves e listas do dicionário
    for col_name, values in d.items():
        # Adicionar as células com os valores da lista na coluna correspondente
        divisao[col_name] = values

refatorar_indece(divisao, 'Ordem')
divisao
# Out:
#        29_28  27_26  25_24  23_22  21_20  19_18
# Ordem
# 1          1      3      5      6      4      2
# 2          7      9     11     12     10      8
# 3         13     15     17     18     16     14
# 4         19     21     23     24     22     20
# 5         25     27     29     30     28     26
# 6         31     33     35     36     34     32
# 7         37     39     41     42     40     38
# 8         43     45     47     48     46     44

# %%
div_desc = divisao.replace(desc_xpe)

refatorar_indece(div_desc, 'Ordem')
div_desc.to_excel('analises_prontas\ordem\divisão_por_desc_xpe.xlsx')

div_desc
# Out:
#                                         29_28  \
# Ordem
# 1                       EMSEXPECTOR XPE 120ML
# 2            ACETILCISTEINA 20MG/ML XPE 120ML
# 3                 CARBOCISTEINA XPE AD  100ML
# 4                 LORATADINA 1MG/ML XPE 100ML
# 5            ACETILCISTEINA 40MG/ML XPE 120ML
# 6      LACTULIV 667MG/ML SOL SAL.FRUTAS 120ML
# 7                 DIPIRONA SOD SOL ORAL 100ML
# 8                     BROMEXINA XPE INF 120ML
#
#                                      27_26  \
# Ordem
# 1                       CELERGIN XPE 120ML
# 2              DEXCLORFENIRAMINA XPE 120ML
# 3             BISURAN XPE AD 8MG/5ML 120ML
# 4            BISURAN XPE INF 4MG/5ML 120ML
# 5      NORMOLAX AMEIXA  667MG/ML SOL 120ML
# 6         ACETILCISTEINA 20MG/ML XPE 120ML
# 7          BRONDELIX 7MG/ML XPE FR C/100ML
# 8         ACETILCISTEINA 20MG/ML XPE 120ML
#
#                                     25_24                             23_22  \
# Ordem
# 1               CLOPE 3,54MG/ML XPE 120ML        EXPEC-TAMIN SOL ORAL 120ML
# 2                        CELERG XPE 120ML     POLAPIC 0,4MG/ML SOL OR 120ML
# 3      LACTULIV 667MG/ML SOL AMEIXA 120ML    HIXILERG 2MG/ML SOL ORAL 120ML
# 4           EXPECTUSS INFANTIL FR C/100ML             AMBROXOL XPE AD 120ML
# 5        FLUITEINA XPE INF 20MG//ML 120ML  CEFALEXINA SUSP 250MG (AM) 100ML
# 6             DIPIRONA SOD SOL ORAL 100ML       CARBOCISTEINA XPE INF 100ML
# 7                    DEXCL+BETA XPE 120ML        HIDROXIZINA SOL ORAL 120ML
# 8              HISTAMIN XPE 2MG/5ML 100ML                                48
#
#                                          21_20  \
# Ordem
# 1                  DIPIRONA SOD SOL ORAL 100ML
# 2                    DEXAMETASONA ELIXIR 120ML
# 3      EXPEC HEDRA 7MG/ML SOL ORAL C/ 100 ML-L
# 4           IBUFLEX 100MG/ML SUSP ORAL C/ 30ML
# 5                  COMPLEXO B12 XPE FR C/120ML
# 6               FLUITEINA XPE AD 40MG/ML 120ML
# 7        NORMOLAX SAL FRUTAS 667MG/ML SOL120ML
# 8                    SULFA+TRI SUSP (AM) 100ML
#
#                                       19_18
# Ordem
# 1                   EXPEC XAROPE FR C/120ML
# 2                      DEXCL+BETA XPE 120ML
# 3                    AMBROXOL XPE INF 120ML
# 4               EXPECTUSS ADULTO FR C/100ML
# 5          ACETILCISTEINA 40MG/ML XPE 120ML
# 6      CLOPERASTINA XPE 3,54 MG/ML C/120 ML
# 7                HIDROXIZINA SOL ORAL 120ML
# 8                 BETAMETASONA ELIXIR 120ML

# %%
div_cod = divisao.replace(cod_xpe)

refatorar_indece(div_cod, 'Ordem')
div_cod.to_excel('analises_prontas\ordem\divisão_por_cod_xpe.xlsx')

div_cod
# Out:
#         29_28   27_26   25_24   23_22   21_20   19_18
# Ordem
# 1      101190  101066  102322  231262   10583  231012
# 2       10579   10220  231048  102379   10160   10198
# 3       10066  101318  231933  101185  232484   10191
# 4       10131  101072  101015   10190  231225  101016
# 5       14265  102245  101163   10168  102383   14265
# 6      231936   12511   12515   10067  101364   11118
# 7       14344  102467   12523   14571  102246   12752
# 8       10745   14340  110287      48   10169   10197

# %%
saida_xpe = divisao.replace(saida_xpe)

refatorar_indece(saida_xpe, 'Ordem')
div_cod.to_excel('analises_prontas\ordem\saida_xpe.xlsx')

saida_xpe
# Out:
#         29_28  27_26  25_24  23_22  21_20   19_18
# Ordem
# 1      210821  74443  52953  39998  65478  202491
# 2       39224  30624  23483  21529  25839   31656
# 3       15778  13781  11543  10788  12627   14011
# 4       10033   8195   7294   6867   8119    9544
# 5        6706   5399   4413   3836   5278    6706
# 6        3575   2983   2505   2466   2743    3475
# 7        2312   1891   1624   1594   1851    1914
# 8        1568   1168   1034     48   1141    1355

# %%
junto = pd.concat([div_desc, div_cod, divisao, saida_xpe])
junto.to_excel('analises_prontas\ordem\cod_mais_desc_xpe.xlsx')
junto
# Out:
#                                         29_28  \
# Ordem
# 1                       EMSEXPECTOR XPE 120ML
# 2            ACETILCISTEINA 20MG/ML XPE 120ML
# 3                 CARBOCISTEINA XPE AD  100ML
# 4                 LORATADINA 1MG/ML XPE 100ML
# 5            ACETILCISTEINA 40MG/ML XPE 120ML
# 6      LACTULIV 667MG/ML SOL SAL.FRUTAS 120ML
# 7                 DIPIRONA SOD SOL ORAL 100ML
# 8                     BROMEXINA XPE INF 120ML
# 1                                      101190
# 2                                       10579
# 3                                       10066
# 4                                       10131
# 5                                       14265
# 6                                      231936
# 7                                       14344
# 8                                       10745
# 1                                           1
# 2                                           7
# 3                                          13
# 4                                          19
# 5                                          25
# 6                                          31
# 7                                          37
# 8                                          43
# 1                                      210821
# 2                                       39224
# 3                                       15778
# 4                                       10033
# 5                                        6706
# 6                                        3575
# 7                                        2312
# 8                                        1568
#
#                                      27_26  \
# Ordem
# 1                       CELERGIN XPE 120ML
# 2              DEXCLORFENIRAMINA XPE 120ML
# 3             BISURAN XPE AD 8MG/5ML 120ML
# 4            BISURAN XPE INF 4MG/5ML 120ML
# 5      NORMOLAX AMEIXA  667MG/ML SOL 120ML
# 6         ACETILCISTEINA 20MG/ML XPE 120ML
# 7          BRONDELIX 7MG/ML XPE FR C/100ML
# 8         ACETILCISTEINA 20MG/ML XPE 120ML
# 1                                   101066
# 2                                    10220
# 3                                   101318
# 4                                   101072
# 5                                   102245
# 6                                    12511
# 7                                   102467
# 8                                    14340
# 1                                        3
# 2                                        9
# 3                                       15
# 4                                       21
# 5                                       27
# 6                                       33
# 7                                       39
# 8                                       45
# 1                                    74443
# 2                                    30624
# 3                                    13781
# 4                                     8195
# 5                                     5399
# 6                                     2983
# 7                                     1891
# 8                                     1168
#
#                                     25_24                             23_22  \
# Ordem
# 1               CLOPE 3,54MG/ML XPE 120ML        EXPEC-TAMIN SOL ORAL 120ML
# 2                        CELERG XPE 120ML     POLAPIC 0,4MG/ML SOL OR 120ML
# 3      LACTULIV 667MG/ML SOL AMEIXA 120ML    HIXILERG 2MG/ML SOL ORAL 120ML
# 4           EXPECTUSS INFANTIL FR C/100ML             AMBROXOL XPE AD 120ML
# 5        FLUITEINA XPE INF 20MG//ML 120ML  CEFALEXINA SUSP 250MG (AM) 100ML
# 6             DIPIRONA SOD SOL ORAL 100ML       CARBOCISTEINA XPE INF 100ML
# 7                    DEXCL+BETA XPE 120ML        HIDROXIZINA SOL ORAL 120ML
# 8              HISTAMIN XPE 2MG/5ML 100ML                                48
# 1                                  102322                            231262
# 2                                  231048                            102379
# 3                                  231933                            101185
# 4                                  101015                             10190
# 5                                  101163                             10168
# 6                                   12515                             10067
# 7                                   12523                             14571
# 8                                  110287                                48
# 1                                       5                                 6
# 2                                      11                                12
# 3                                      17                                18
# 4                                      23                                24
# 5                                      29                                30
# 6                                      35                                36
# 7                                      41                                42
# 8                                      47                                48
# 1                                   52953                             39998
# 2                                   23483                             21529
# 3                                   11543                             10788
# 4                                    7294                              6867
# 5                                    4413                              3836
# 6                                    2505                              2466
# 7                                    1624                              1594
# 8                                    1034                                48
#
#                                          21_20  \
# Ordem
# 1                  DIPIRONA SOD SOL ORAL 100ML
# 2                    DEXAMETASONA ELIXIR 120ML
# 3      EXPEC HEDRA 7MG/ML SOL ORAL C/ 100 ML-L
# 4           IBUFLEX 100MG/ML SUSP ORAL C/ 30ML
# 5                  COMPLEXO B12 XPE FR C/120ML
# 6               FLUITEINA XPE AD 40MG/ML 120ML
# 7        NORMOLAX SAL FRUTAS 667MG/ML SOL120ML
# 8                    SULFA+TRI SUSP (AM) 100ML
# 1                                        10583
# 2                                        10160
# 3                                       232484
# 4                                       231225
# 5                                       102383
# 6                                       101364
# 7                                       102246
# 8                                        10169
# 1                                            4
# 2                                           10
# 3                                           16
# 4                                           22
# 5                                           28
# 6                                           34
# 7                                           40
# 8                                           46
# 1                                        65478
# 2                                        25839
# 3                                        12627
# 4                                         8119
# 5                                         5278
# 6                                         2743
# 7                                         1851
# 8                                         1141
#
#                                       19_18
# Ordem
# 1                   EXPEC XAROPE FR C/120ML
# 2                      DEXCL+BETA XPE 120ML
# 3                    AMBROXOL XPE INF 120ML
# 4               EXPECTUSS ADULTO FR C/100ML
# 5          ACETILCISTEINA 40MG/ML XPE 120ML
# 6      CLOPERASTINA XPE 3,54 MG/ML C/120 ML
# 7                HIDROXIZINA SOL ORAL 120ML
# 8                 BETAMETASONA ELIXIR 120ML
# 1                                    231012
# 2                                     10198
# 3                                     10191
# 4                                    101016
# 5                                     14265
# 6                                     11118
# 7                                     12752
# 8                                     10197
# 1                                         2
# 2                                         8
# 3                                        14
# 4                                        20
# 5                                        26
# 6                                        32
# 7                                        38
# 8                                        44
# 1                                    202491
# 2                                     31656
# 3                                     14011
# 4                                      9544
# 5                                      6706
# 6                                      3475
# 7                                      1914
# 8                                      1355
