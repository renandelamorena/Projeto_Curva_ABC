# %% [markdown]
# # Importando Bibliotecas

# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %% [markdown]
# # Importando Dados

# %%
produtos = pd.read_excel('datasets\produtos.xlsx')

# %%
curva_geral = pd.read_excel('datasets\curva_geral.xlsx')

# %% [markdown]
# # Tratando Dados

# %% [markdown]
# # Funções

# %%
def tratar_codigos(dfs):
    
    for df in dfs:
        
        df['Cód.Produto'] = df['Cód.Produto'].astype(str)

        df['Cód.Produto'] = df['Cód.Produto'].str.slice(start=2)
        df['Cód.Produto'] = df['Cód.Produto'].str.lstrip('0')

    return df

# %% [markdown]
# ## Tratamento Cadastro

# %%
# exclui colunas irrelevantes para analise
colunas_irrelevantes = ['Qtde em Receb.',
                        'Estoque Armaz.',
                        'Descrição',
                        'Embal..1',
                       ]
produtos = produtos.drop(colunas_irrelevantes, axis = 1)

# renomeia coluna de cod
renomear_produtos = {'Código':'Cód.Produto',
                     'Apanha' : 'Apanha Cx',
                     'Apanha.1' : 'Apanha Frac',
                     'Capacidade' : 'Capacidade Cx',
                     'Capacidade.1' : 'Capacidade Frac',
                     'Estoque.1' : 'Estoque Frac',
                     'Estoque' : 'Estoque Cx',
                    }
produtos.rename(columns = renomear_produtos, inplace = True)

# exclui linhas completamente vazias
produtos = produtos.dropna(how='all')

# %% [markdown]
#  ## Tratamento Curvas

# %%
# exclui colunas irrelevantes para analise
colunas_irrelevantes_curva = ['Qtde Acumulada',
                              'Perc.',
                              'Perc.Capacid.Apan.',
                              'Perc.Acumulada',
                              'Embal.',
                              'Endereço Apanha',
                              'Tipo Ender.',
                             ]

curva_geral = curva_geral.drop(colunas_irrelevantes_curva, axis = 1)

# exclui linhas completamente vazias
curva_geral = curva_geral.dropna(how='all')

# %% [markdown]
# ## Tratanndo códigos

# %%
dfs = [curva_geral, produtos]
tratar_codigos(dfs)
# Out:
#      Cód.Produto Apanha Cx Permite Frac. Ender.Cx.Fechada  Embal.  \
# 0       460000.0       Sim           Não    014-026-01-02    35.0
# 1        10531.0       Sim           Sim    010-014-01-02    40.0
# 2        10424.0       Sim           Não    016-013-01-02    40.0
# 3        10425.0       Sim           Não    015-027-01-02    84.0
# 4        10159.0       Sim           Não    014-010-01-02    24.0
# ...          ...       ...           ...              ...     ...
# 9259     11211.0       Sim           Não    018-001-01-01    60.0
# 9260     29909.0       Não           Não              NaN    60.0
# 9261     29910.0       Sim           Não    018-006-01-01    60.0
# 9262    420655.0       Sim           Não    018-003-01-01    36.0
# 9263     16361.0       Sim           Não    018-001-01-02   100.0
#
#       Capacidade Cx  Estoque Cx Apanha Frac  Ender.Fracionado        Tipo  \
# 0               3.0           3         Sim            28.903  Ponta De G
# 1               2.0  1 (+39 fr)         Sim            28.514  Prateleira
# 2               3.0           3         Sim            25.075    Flowrack
# 3              10.0           8         Sim            26.022    Flowrack
# 4               3.0           0         Sim            24.016    Flowrack
# ...             ...         ...         ...               ...         ...
# 9259            2.0           0         Sim            11.103  Prateleira
# 9260            0.0           0         Não               NaN         NaN
# 9261            3.0           0         Sim            10.207  Prateleira
# 9262            4.0           0         Sim            11.144  Prateleira
# 9263            1.0           1         Sim            11.528  Prateleira
#
#       Capacidade Frac  Estoque Frac
# 0                60.0          46.0
# 1                41.0          38.0
# 2                40.0          46.0
# 3               252.0         209.0
# 4                54.0           0.0
# ...               ...           ...
# 9259            120.0           0.0
# 9260              0.0           0.0
# 9261            120.0           0.0
# 9262             36.0           0.0
# 9263            100.0          90.0
#
# [9246 rows x 12 columns]

# %% [markdown]
# ### Curva Geral

# %%
renomear_geral = {'Estoque (Unid.)' : 'Estoque Chão',
                    'Ativ.Ressupr.' : 'Ativ.Ressupr.Frac',
                    'Curva' : 'Curva Geral',
                    'Qtde Venda' : 'Qtde Venda Geral',
                    'Dias Pedido' : 'Dias Pedido Geral',
                    'Média por dia' : 'Média por dia Geral',
                    'Ativ.Ressupr.' : 'Ativ.Ressupr. Geral',
                    'Capacid.Apan.' : 'Capacid.Chão'
                   }
curva_geral.rename(columns = renomear_geral, inplace = True)

# %%
curva_geral
# Out:
#      Cód.Produto                               Descrição Curva Geral  \
# 0       106011.0             NARIDRIN 12 HORAS FR C/30ML           A
# 1       231012.0                 EXPEC XAROPE FR C/120ML           A
# 2       101190.0                   EMSEXPECTOR XPE 120ML           A
# 3       101175.0                     INFRALAX C/ 15 COMP           A
# 4        10302.0                 LOSARTANA POT 50MG 30CP           A
# ...          ...                                     ...         ...
# 3431    801658.0                 COLCHONETEGR PET NEWS-M           C
# 3432    801659.0                 COLCHONETEGR PET NEWS-P           C
# 3433    802246.0  BRINQ KONG BALLISTIC WOODLAND RABBIT-G           C
# 3434    802356.0      JOGO INTERATIVO PETGAMES CAT PIZZA           C
# 3435     61711.0                        DISPLAY HIDRALIP           C
#
#       Qtde Venda Geral  Dias Pedido Geral  Média por dia Geral  Capacid.Chão  \
# 0            1115940.0              288.0            3874.7917        2000.0
# 1             514689.0              254.0            2026.3346         540.0
# 2             288767.0              242.0            1193.2521         540.0
# 3             180445.0              273.0             660.9707        1872.0
# 4             177240.0              196.0             904.2857        2436.0
# ...                ...                ...                  ...           ...
# 3431               0.0                0.0               0.0000           1.0
# 3432               0.0                0.0               0.0000           1.0
# 3433               0.0                0.0               0.0000           1.0
# 3434               0.0                0.0               0.0000           1.0
# 3435               0.0                0.0               0.0000           0.0
#
#       Estoque Chão  Ativ.Ressupr. Geral  Estoque Armaz. (Unid.)  \
# 0           5795.0               1328.0                254500.0
# 1            920.0                985.0                171900.0
# 2           1465.0               1070.0                 74700.0
# 3           1579.0                711.0                 37968.0
# 4              0.0                194.0                     0.0
# ...            ...                  ...                     ...
# 3431           1.0                  0.0                     0.0
# 3432           1.0                  0.0                     0.0
# 3433           1.0                  0.0                     0.0
# 3434           1.0                  0.0                     0.0
# 3435           0.0                  0.0                    18.0
#
#       Estoque Geral (Unid.)
# 0                  260295.0
# 1                  172820.0
# 2                   76165.0
# 3                   39547.0
# 4                       0.0
# ...                     ...
# 3431                    1.0
# 3432                    1.0
# 3433                    1.0
# 3434                    1.0
# 3435                   18.0
#
# [3430 rows x 11 columns]

# %% [markdown]
# ## Juntando as informações

# %%
curva_abc_geral = pd.merge(curva_geral, produtos, on='Cód.Produto', how='outer')

curva_abc_geral['Cód.Produto'] = pd.to_numeric(curva_abc_geral['Cód.Produto'])

curva_abc_geral['Ender.Fracionado'] = curva_abc_geral['Ender.Fracionado'].astype(str)

curva_abc_geral
# Out:
#       Cód.Produto                    Descrição Curva Geral  Qtde Venda Geral  \
# 0        106011.0  NARIDRIN 12 HORAS FR C/30ML           A         1115940.0
# 1        231012.0      EXPEC XAROPE FR C/120ML           A          514689.0
# 2        101190.0        EMSEXPECTOR XPE 120ML           A          288767.0
# 3        101175.0          INFRALAX C/ 15 COMP           A          180445.0
# 4         10302.0      LOSARTANA POT 50MG 30CP           A          177240.0
# ...           ...                          ...         ...               ...
# 9260     421840.0                          NaN         NaN               NaN
# 9261     316036.0                          NaN         NaN               NaN
# 9262      11211.0                          NaN         NaN               NaN
# 9263      29909.0                          NaN         NaN               NaN
# 9264     420655.0                          NaN         NaN               NaN
#
#       Dias Pedido Geral  Média por dia Geral  Capacid.Chão  Estoque Chão  \
# 0                 288.0            3874.7917        2000.0        5795.0
# 1                 254.0            2026.3346         540.0         920.0
# 2                 242.0            1193.2521         540.0        1465.0
# 3                 273.0             660.9707        1872.0        1579.0
# 4                 196.0             904.2857        2436.0           0.0
# ...                 ...                  ...           ...           ...
# 9260                NaN                  NaN           NaN           NaN
# 9261                NaN                  NaN           NaN           NaN
# 9262                NaN                  NaN           NaN           NaN
# 9263                NaN                  NaN           NaN           NaN
# 9264                NaN                  NaN           NaN           NaN
#
#       Ativ.Ressupr. Geral  Estoque Armaz. (Unid.)  Estoque Geral (Unid.)  \
# 0                  1328.0                254500.0               260295.0
# 1                   985.0                171900.0               172820.0
# 2                  1070.0                 74700.0                76165.0
# 3                   711.0                 37968.0                39547.0
# 4                   194.0                     0.0                    0.0
# ...                   ...                     ...                    ...
# 9260                  NaN                     NaN                    NaN
# 9261                  NaN                     NaN                    NaN
# 9262                  NaN                     NaN                    NaN
# 9263                  NaN                     NaN                    NaN
# 9264                  NaN                     NaN                    NaN
#
#      Apanha Cx Permite Frac. Ender.Cx.Fechada  Embal.  Capacidade Cx  \
# 0          Sim           Não    016-037-01-01   100.0           15.0
# 1          Sim           Não    016-043-01-02    60.0            5.0
# 2          Sim           Não    016-035-01-02    60.0            5.0
# 3          Sim           Não    014-032-02-01    48.0           30.0
# 4          Sim           Não    015-033-01-01    84.0           25.0
# ...        ...           ...              ...     ...            ...
# 9260       Sim           Não    018-001-01-02    96.0            1.0
# 9261       Sim           Não    018-004-01-02   100.0            2.0
# 9262       Sim           Não    018-001-01-01    60.0            2.0
# 9263       Não           Não              NaN    60.0            0.0
# 9264       Sim           Não    018-003-01-01    36.0            4.0
#
#      Estoque Cx Apanha Frac Ender.Fracionado        Tipo  Capacidade Frac  \
# 0            67         Sim           18.903  Ponta De G            500.0
# 1            15         Sim           29.913  Ponta De G            240.0
# 2            25         Sim           29.075    Flowrack            240.0
# 3            25         Sim           25.064    Flowrack            432.0
# 4             0         Sim           27.072    Flowrack            336.0
# ...         ...         ...              ...         ...              ...
# 9260          0         Não              nan         NaN              0.0
# 9261          0         Não              nan         NaN              0.0
# 9262          0         Sim           11.103  Prateleira            120.0
# 9263          0         Não              nan         NaN              0.0
# 9264          0         Sim           11.144  Prateleira             36.0
#
#       Estoque Frac
# 0            376.0
# 1            104.0
# 2            223.0
# 3            393.0
# 4              0.0
# ...            ...
# 9260           0.0
# 9261           0.0
# 9262           0.0
# 9263           0.0
# 9264           0.0
#
# [9265 rows x 22 columns]

# %%
qnt_linha = curva_abc_geral.shape[0] + 1

index = [i for i in range(1, qnt_linha)]

curva_abc_geral.set_index(pd.Index(index), inplace=True)

curva_abc_geral.index.name = 'Ordem'
curva_abc_geral
# Out:
#        Cód.Produto                    Descrição Curva Geral  Qtde Venda Geral  \
# Ordem
# 1         106011.0  NARIDRIN 12 HORAS FR C/30ML           A         1115940.0
# 2         231012.0      EXPEC XAROPE FR C/120ML           A          514689.0
# 3         101190.0        EMSEXPECTOR XPE 120ML           A          288767.0
# 4         101175.0          INFRALAX C/ 15 COMP           A          180445.0
# 5          10302.0      LOSARTANA POT 50MG 30CP           A          177240.0
# ...            ...                          ...         ...               ...
# 9261      421840.0                          NaN         NaN               NaN
# 9262      316036.0                          NaN         NaN               NaN
# 9263       11211.0                          NaN         NaN               NaN
# 9264       29909.0                          NaN         NaN               NaN
# 9265      420655.0                          NaN         NaN               NaN
#
#        Dias Pedido Geral  Média por dia Geral  Capacid.Chão  Estoque Chão  \
# Ordem
# 1                  288.0            3874.7917        2000.0        5795.0
# 2                  254.0            2026.3346         540.0         920.0
# 3                  242.0            1193.2521         540.0        1465.0
# 4                  273.0             660.9707        1872.0        1579.0
# 5                  196.0             904.2857        2436.0           0.0
# ...                  ...                  ...           ...           ...
# 9261                 NaN                  NaN           NaN           NaN
# 9262                 NaN                  NaN           NaN           NaN
# 9263                 NaN                  NaN           NaN           NaN
# 9264                 NaN                  NaN           NaN           NaN
# 9265                 NaN                  NaN           NaN           NaN
#
#        Ativ.Ressupr. Geral  Estoque Armaz. (Unid.)  Estoque Geral (Unid.)  \
# Ordem
# 1                   1328.0                254500.0               260295.0
# 2                    985.0                171900.0               172820.0
# 3                   1070.0                 74700.0                76165.0
# 4                    711.0                 37968.0                39547.0
# 5                    194.0                     0.0                    0.0
# ...                    ...                     ...                    ...
# 9261                   NaN                     NaN                    NaN
# 9262                   NaN                     NaN                    NaN
# 9263                   NaN                     NaN                    NaN
# 9264                   NaN                     NaN                    NaN
# 9265                   NaN                     NaN                    NaN
#
#       Apanha Cx Permite Frac. Ender.Cx.Fechada  Embal.  Capacidade Cx  \
# Ordem
# 1           Sim           Não    016-037-01-01   100.0           15.0
# 2           Sim           Não    016-043-01-02    60.0            5.0
# 3           Sim           Não    016-035-01-02    60.0            5.0
# 4           Sim           Não    014-032-02-01    48.0           30.0
# 5           Sim           Não    015-033-01-01    84.0           25.0
# ...         ...           ...              ...     ...            ...
# 9261        Sim           Não    018-001-01-02    96.0            1.0
# 9262        Sim           Não    018-004-01-02   100.0            2.0
# 9263        Sim           Não    018-001-01-01    60.0            2.0
# 9264        Não           Não              NaN    60.0            0.0
# 9265        Sim           Não    018-003-01-01    36.0            4.0
#
#       Estoque Cx Apanha Frac Ender.Fracionado        Tipo  Capacidade Frac  \
# Ordem
# 1             67         Sim           18.903  Ponta De G            500.0
# 2             15         Sim           29.913  Ponta De G            240.0
# 3             25         Sim           29.075    Flowrack            240.0
# 4             25         Sim           25.064    Flowrack            432.0
# 5              0         Sim           27.072    Flowrack            336.0
# ...          ...         ...              ...         ...              ...
# 9261           0         Não              nan         NaN              0.0
# 9262           0         Não              nan         NaN              0.0
# 9263           0         Sim           11.103  Prateleira            120.0
# 9264           0         Não              nan         NaN              0.0
# 9265           0         Sim           11.144  Prateleira             36.0
#
#        Estoque Frac
# Ordem
# 1             376.0
# 2             104.0
# 3             223.0
# 4             393.0
# 5               0.0
# ...             ...
# 9261            0.0
# 9262            0.0
# 9263            0.0
# 9264            0.0
# 9265            0.0
#
# [9265 rows x 22 columns]

# %%
curva_abc_geral.to_excel('dados_tratados\curva_abc_geral.xlsx')
