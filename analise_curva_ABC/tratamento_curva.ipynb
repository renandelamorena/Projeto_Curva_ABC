# %% [markdown]
# # Importando Bibliotecas

# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %% [markdown]
# # Importando Dados

# %%
produtos = pd.read_excel('datasets\produtos.xlsx')

# %%
curva_geral = pd.read_excel('datasets\curva_geral.xlsx')

# %% [markdown]
# # Tratando Dados

# %% [markdown]
# # Funções

# %%
def tratar_codigos(dfs):
    
    for df in dfs:
        
        df['Cód.Produto'] = df['Cód.Produto'].astype(str)

        df['Cód.Produto'] = df['Cód.Produto'].str.slice(start=2)
        df['Cód.Produto'] = df['Cód.Produto'].str.lstrip('0')

    return df

# %% [markdown]
# ## Tratamento Cadastro

# %%
# exclui colunas irrelevantes para analise
colunas_irrelevantes = ['Qtde em Receb.',
                        'Estoque Armaz.',
                        'Descrição',
                        'Embal..1',
                       ]
produtos = produtos.drop(colunas_irrelevantes, axis = 1)

# renomeia coluna de cod
renomear_produtos = {'Código':'Cód.Produto',
                     'Apanha' : 'Apanha Cx',
                     'Apanha.1' : 'Apanha Frac',
                     'Capacidade' : 'Capacidade Cx',
                     'Capacidade.1' : 'Capacidade Frac',
                     'Estoque.1' : 'Estoque Frac',
                     'Estoque' : 'Estoque Cx',
                    }
produtos.rename(columns = renomear_produtos, inplace = True)

# exclui linhas completamente vazias
produtos = produtos.dropna(how='all')

# %% [markdown]
#  ## Tratamento Curvas

# %%
# exclui colunas irrelevantes para analise
colunas_irrelevantes_curva = ['Qtde Acumulada',
                              'Perc.',
                              'Perc.Capacid.Apan.',
                              'Perc.Acumulada',
                              'Embal.',
                              'Endereço Apanha',
                              'Tipo Ender.',
                             ]

curva_geral = curva_geral.drop(colunas_irrelevantes_curva, axis = 1)

# exclui linhas completamente vazias
curva_geral = curva_geral.dropna(how='all')

# %% [markdown]
# ## Tratanndo códigos

# %%
dfs = [curva_geral, produtos]
tratar_codigos(dfs)
# Out:
#      Cód.Produto Apanha Cx Permite Frac. Ender.Cx.Fechada  Embal.  \
# 0       460000.0       Sim           Não    015-025-01-02    30.0
# 1        10531.0       Sim           Não    014-018-01-01    40.0
# 2        10424.0       Sim           Não    016-013-01-02    40.0
# 3        10425.0       Sim           Não    015-027-01-02    84.0
# 4        10159.0       Sim           Não    014-010-01-02    24.0
# ...          ...       ...           ...              ...     ...
# 8873     11211.0       Sim           Não    018-001-01-01    60.0
# 8874     29909.0       Não           Não              NaN    60.0
# 8875     12721.0       Sim           Não    018-005-01-01    60.0
# 8876     29910.0       Sim           Não    018-006-01-01    60.0
# 8877    420655.0       Sim           Não    018-003-01-01    36.0
#
#       Capacidade Cx Estoque Cx Apanha Frac  Ender.Fracionado        Tipo  \
# 0               4.0          4         Sim            28.903  Ponta De G
# 1               3.0          3         Sim            28.182  Prateleira
# 2               3.0          3         Sim            25.075    Flowrack
# 3              10.0          9         Sim            27.901  Ponta De G
# 4               3.0          2         Sim            24.016    Flowrack
# ...             ...        ...         ...               ...         ...
# 8873            2.0          0         Sim            11.103  Prateleira
# 8874            0.0          0         Não               NaN         NaN
# 8875            2.0          0         Sim            11.508  Prateleira
# 8876            3.0          0         Sim            10.207  Prateleira
# 8877            4.0          0         Sim            11.144  Prateleira
#
#       Capacidade Frac  Estoque Frac
# 0                60.0          11.0
# 1               100.0         103.0
# 2                40.0          37.0
# 3               252.0          82.0
# 4                54.0          61.0
# ...               ...           ...
# 8873            120.0           0.0
# 8874              0.0           0.0
# 8875             60.0          20.0
# 8876            120.0           0.0
# 8877             36.0           0.0
#
# [8861 rows x 12 columns]

# %% [markdown]
# ### Curva Geral

# %%
renomear_geral = {'Estoque (Unid.)' : 'Estoque Chão',
                    'Ativ.Ressupr.' : 'Ativ.Ressupr.Frac',
                    'Curva' : 'Curva Geral',
                    'Qtde Venda' : 'Qtde Venda Geral',
                    'Dias Pedido' : 'Dias Pedido Geral',
                    'Média por dia' : 'Média por dia Geral',
                    'Ativ.Ressupr.' : 'Ativ.Ressupr. Geral',
                    'Capacid.Apan.' : 'Capacid.Chão'
                   }
curva_geral.rename(columns = renomear_geral, inplace = True)

# %%
curva_geral
# Out:
#      Cód.Produto                                Descrição Curva Geral  \
# 0       106011.0              NARIDRIN 12 HORAS FR C/30ML           A
# 1       231012.0                  EXPEC XAROPE FR C/120ML           A
# 2       101190.0                    EMSEXPECTOR XPE 120ML           A
# 3       101175.0                      INFRALAX C/ 15 COMP           A
# 4       102138.0                       INFRALAX C/30 COMP           A
# ...          ...                                      ...         ...
# 3873     60932.0  DISPLAY CHAO 4 GANCHEIRAS THE FRENCH CO           C
# 3874     61467.0    TOALHAS PROPLAN DE PRAIA PURINA 6 UND           C
# 3875     63026.0                       CLIP STRIP SOMINEX           C
# 3876     63336.0                        DISPLAY TOTEM EMS           C
# 3877    801659.0                  COLCHONETEGR PET NEWS-P           C
#
#       Qtde Venda Geral  Dias Pedido Geral  Média por dia Geral  Capacid.Chão  \
# 0            1148435.0              271.0            4237.7675        3500.0
# 1             342057.0              199.0            1718.8794        1020.0
# 2             246096.0              177.0            1390.3729         960.0
# 3             173121.0              268.0             645.9739        1584.0
# 4             163324.0              267.0             611.7004        1824.0
# ...                ...                ...                  ...           ...
# 3873               0.0                0.0               0.0000           1.0
# 3874               0.0                0.0               0.0000           1.0
# 3875               0.0                0.0               0.0000           1.0
# 3876               0.0                0.0               0.0000           1.0
# 3877               0.0                0.0               0.0000           1.0
#
#       Estoque Chão  Ativ.Ressupr. Geral  Estoque Armaz. (Unid.)  \
# 0           2835.0               1353.0                368400.0
# 1            625.0                536.0                 63240.0
# 2            293.0                429.0                 97080.0
# 3           1205.0                634.0                 32352.0
# 4           1167.0                559.0                 26064.0
# ...            ...                  ...                     ...
# 3873           2.0                  0.0                     0.0
# 3874           4.0                  0.0                     0.0
# 3875           1.0                  0.0                   349.0
# 3876           3.0                  0.0                     0.0
# 3877           1.0                  0.0                     0.0
#
#       Estoque Geral (Unid.)
# 0                  371235.0
# 1                   63865.0
# 2                   97373.0
# 3                   33557.0
# 4                   27231.0
# ...                     ...
# 3873                    2.0
# 3874                    4.0
# 3875                  350.0
# 3876                    3.0
# 3877                    1.0
#
# [3871 rows x 11 columns]

# %% [markdown]
# ## Juntando as informações

# %%
curva_abc_geral = pd.merge(curva_geral, produtos, on='Cód.Produto', how='outer')

curva_abc_geral['Cód.Produto'] = pd.to_numeric(curva_abc_geral['Cód.Produto'])

curva_abc_geral['Ender.Fracionado'] = curva_abc_geral['Ender.Fracionado'].astype(str)

curva_abc_geral
# Out:
#       Cód.Produto                    Descrição Curva Geral  Qtde Venda Geral  \
# 0        106011.0  NARIDRIN 12 HORAS FR C/30ML           A         1148435.0
# 1        231012.0      EXPEC XAROPE FR C/120ML           A          342057.0
# 2        101190.0        EMSEXPECTOR XPE 120ML           A          246096.0
# 3        101175.0          INFRALAX C/ 15 COMP           A          173121.0
# 4        102138.0           INFRALAX C/30 COMP           A          163324.0
# ...           ...                          ...         ...               ...
# 8940     130073.0                          NaN         NaN               NaN
# 8941     421840.0                          NaN         NaN               NaN
# 8942     316036.0                          NaN         NaN               NaN
# 8943      11211.0                          NaN         NaN               NaN
# 8944      29909.0                          NaN         NaN               NaN
#
#       Dias Pedido Geral  Média por dia Geral  Capacid.Chão  Estoque Chão  \
# 0                 271.0            4237.7675        3500.0        2835.0
# 1                 199.0            1718.8794        1020.0         625.0
# 2                 177.0            1390.3729         960.0         293.0
# 3                 268.0             645.9739        1584.0        1205.0
# 4                 267.0             611.7004        1824.0        1167.0
# ...                 ...                  ...           ...           ...
# 8940                NaN                  NaN           NaN           NaN
# 8941                NaN                  NaN           NaN           NaN
# 8942                NaN                  NaN           NaN           NaN
# 8943                NaN                  NaN           NaN           NaN
# 8944                NaN                  NaN           NaN           NaN
#
#       Ativ.Ressupr. Geral  Estoque Armaz. (Unid.)  Estoque Geral (Unid.)  \
# 0                  1353.0                368400.0               371235.0
# 1                   536.0                 63240.0                63865.0
# 2                   429.0                 97080.0                97373.0
# 3                   634.0                 32352.0                33557.0
# 4                   559.0                 26064.0                27231.0
# ...                   ...                     ...                    ...
# 8940                  NaN                     NaN                    NaN
# 8941                  NaN                     NaN                    NaN
# 8942                  NaN                     NaN                    NaN
# 8943                  NaN                     NaN                    NaN
# 8944                  NaN                     NaN                    NaN
#
#      Apanha Cx Permite Frac. Ender.Cx.Fechada  Embal.  Capacidade Cx  \
# 0          Sim           Não    010-018-01-02   100.0           30.0
# 1          Sim           Não    014-028-01-02    60.0            5.0
# 2          Sim           Não    014-040-01-01    60.0            4.0
# 3          Sim           Não    014-032-02-01    48.0           36.0
# 4          Sim           Não    014-042-02-01    48.0           30.0
# ...        ...           ...              ...     ...            ...
# 8940       Não           Não              NaN    60.0            0.0
# 8941       Sim           Não    018-001-01-02    96.0            1.0
# 8942       Sim           Não    018-004-01-02   100.0            2.0
# 8943       Sim           Não    018-001-01-01    60.0            2.0
# 8944       Não           Não              NaN    60.0            0.0
#
#      Estoque Cx Apanha Frac Ender.Fracionado        Tipo  Capacidade Frac  \
# 0            28         Sim           18.903  Ponta De G            500.0
# 1             0         Sim           29.086    Flowrack            240.0
# 2             0         Sim           29.075    Flowrack            240.0
# 3            32         Sim           25.081    Flowrack            384.0
# 4            17         Sim           29.081    Flowrack            480.0
# ...         ...         ...              ...         ...              ...
# 8940          0         Não              nan         NaN              0.0
# 8941          0         Sim           10.066    Flowrack             96.0
# 8942          0         Não              nan         NaN              0.0
# 8943          0         Sim           11.103  Prateleira            120.0
# 8944          0         Não              nan         NaN              0.0
#
#       Estoque Frac
# 0            381.0
# 1             18.0
# 2             88.0
# 3            311.0
# 4            422.0
# ...            ...
# 8940           0.0
# 8941           0.0
# 8942           0.0
# 8943           0.0
# 8944           0.0
#
# [8945 rows x 22 columns]

# %%
curva_abc_geral.to_excel('dados_tratados\curva_abc_geral.xlsx')
