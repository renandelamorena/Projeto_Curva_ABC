# %% [markdown]
# # Importando Bibliotecas

# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %% [markdown]
# # Importando Dados

# %%
produtos = pd.read_excel('datasets\produtos.xlsx')

# %%
curva_geral = pd.read_excel('datasets\curva_geral.xlsx')

# %%
curva_cx = pd.read_excel('datasets\curva_cx.xlsx')

# %%
curva_frac = pd.read_excel('datasets\curva_frac.xlsx')

# %% [markdown]
# # Tratando Dados

# %% [markdown]
# # Funções

# %%
def tratar_codigos(dfs):
    
    for df in dfs:
        
        df['Código'] = df['Código'].astype(str)

        df['Código'] = df['Código'].str.slice(start=2)
        df['Código'] = df['Código'].str.lstrip('0')

    return df

# %%
def refatorar_indece(df, nome_index):
    
    qnt_linha = df.shape[0] + 1

    index = [i for i in range(1, qnt_linha)]

    df.set_index(pd.Index(index), inplace=True)

    df.index.name = nome_index
    
    return df

# %%
def procurar(df, coluna, oque):
    
    selecao = df[coluna] == oque
    
    return df[selecao]

# %% [markdown]
# ## Tratamento cadastro produtos

# %%
# Excluir linhas vazias
produtos = produtos.dropna(how='all')

# Selecionando somente as principais colunas
produtos = produtos[['Código',
                     'Descrição',
                     'Estoque Armaz.',
                     'Apanha',
                     'Permite Frac.',
                     'Ender.Cx.Fechada',
                     'Embal.',
                     'Capacidade',
                     'Estoque',
                     'Apanha.1',
                     'Ender.Fracionado',
                     'Tipo',
                     'Capacidade.1',
                     'Estoque.1'
                    ]]

# Renomear colunas de geral
renomear_produtos = {'Apanha.1' : 'Apanha Frac',
                    'Apanha' : 'Apanha Cx',
                    'Capacidade.1' : 'Capacidade Frac',
                    'Capacidade' : 'Capacidade Cx',
                    'Estoque.1' : 'Estoque Frac',
                    'Estoque' : 'Estoque Cx'
                   }

produtos.rename(columns = renomear_produtos, inplace = True)

# %% [markdown]
#  ## Tratamento Curvas

# %% [markdown]
# ### Geral

# %%
# Excluir linhas vazias
curva_geral = curva_geral.dropna(how='all')

# Selecionando somente as principais colunas
curva_geral = curva_geral[['Cód.Produto', 'Curva', 'Qtde Venda', 'Dias Pedido', 'Média por dia', 'Ativ.Ressupr.']]

# Renomear colunas de geral
renomear_geral = {'Cód.Produto' : 'Código',
                   'Curva' : 'Curva Geral',
                   'Qtde Venda' : 'Qtde Venda Geral',
                   'Dias Pedido' : 'Dias Pedido Geral',
                   'Média por dia' : 'Média por dia geral',
                   'Ativ.Ressupr.' : 'Ativ.Ressupr.Geral',
                  }

curva_geral.rename(columns = renomear_geral, inplace = True)

# %% [markdown]
# ### Fracionado

# %%
# Excluir linhas vazias
curva_frac = curva_frac.dropna(how='all')

# Selecionando somente as principais colunas
curva_frac = curva_frac[['Cód.Produto', 'Curva', 'Qtde Venda', 'Dias Pedido', 'Média por dia', 'Ativ.Ressupr.', 'Qtde Desvio Picking']]

# Renomear colunas de frac
renomear_frac = {'Cód.Produto' : 'Código',
               'Curva' : 'Curva Frac',
               'Qtde Venda' : 'Qtde Venda Frac',
               'Dias Pedido' : 'Dias Pedido Frac',
               'Média por dia' : 'Média por dia frac',
               'Ativ.Ressupr.' : 'Ativ.Ressupr.Frac',
              }

curva_frac.rename(columns = renomear_frac, inplace = True)

# %% [markdown]
# ### Caixa Fechada

# %%
# Excluir linhas vazias
curva_cx = curva_cx.dropna(how='all')

# Selecionando somente as principais colunas
curva_cx = curva_cx[['Cód.Produto', 'Curva', 'Qtde Venda', 'Dias Pedido', 'Média por dia', 'Ativ.Ressupr.']]

# Renomear colunas de cx
renomear_cx = {'Cód.Produto' : 'Código',
               'Curva' : 'Curva Cx',
               'Qtde Venda' : 'Qtde Venda Cx',
               'Dias Pedido' : 'Dias Pedido Cx',
               'Média por dia' : 'Média por dia cx',
               'Ativ.Ressupr.' : 'Ativ.Ressupr.Cx',
              }

curva_cx.rename(columns = renomear_cx, inplace = True)

# %% [markdown]
# ## Tratando códigos

# %%
dfs = [curva_geral, curva_frac, curva_cx, produtos]
tratar_codigos(dfs)
# Out:
#         Código                            Descrição  Estoque Armaz. Apanha Cx  \
# 0     460000.0              A SAUDE DA MULHER 150ML             0.0       Sim
# 1      10531.0                 AAS 100MG C/ 100COMP             0.0       Sim
# 2      10424.0                 AAS 100MG C/ 200COMP             0.0       Sim
# 3      10425.0                  AAS 100MG C/ 30COMP            41.0       Sim
# 4      10159.0                 AAS 500MG C/ 200COMP             0.0       Sim
# ...        ...                                  ...             ...       ...
# 9334   11211.0        ZOLPIDEM 10MG 10CP (B1)** GEN             0.0       Não
# 9335   29909.0         ZOLPIDEM 10MG 10CP (B1)** NQ             0.0       Não
# 9336   29910.0         ZOLPIDEM 10MG 20CP (B1)** NQ             0.0       Sim
# 9337  420655.0       ZOLPIDEM 10MG 20CPR (B1)**EURO             0.0       Não
# 9338   16361.0  ZOLPIDEM 5MG (B1)** C/ 30 COMP SUBL             0.0       Sim
#
#      Permite Frac. Ender.Cx.Fechada  Embal.  Capacidade Cx Estoque Cx  \
# 0              Não    014-026-01-02    35.0            3.0          0
# 1              Sim    010-014-01-02    40.0            2.0  1 (+5 fr)
# 2              Não    016-013-01-02    40.0            3.0          3
# 3              Não    015-027-01-02    84.0           10.0          8
# 4              Não    014-010-01-02    24.0            3.0          0
# ...            ...              ...     ...            ...        ...
# 9334           Não              NaN    60.0            0.0          0
# 9335           Não              NaN    60.0            0.0          0
# 9336           Não    018-006-01-01    60.0            3.0          0
# 9337           Não              NaN    36.0            0.0          0
# 9338           Não    018-001-01-02   100.0            2.0          2
#
#      Apanha Frac  Ender.Fracionado        Tipo  Capacidade Frac  Estoque Frac
# 0            Sim            24.071    Flowrack             60.0           0.0
# 1            Sim            26.144  Prateleira             41.0          92.0
# 2            Sim            21.066    Flowrack            200.0         140.0
# 3            Sim            20.084    Flowrack            252.0         292.0
# 4            Não               NaN         NaN              0.0           0.0
# ...          ...               ...         ...              ...           ...
# 9334         Não               NaN         NaN              0.0           0.0
# 9335         Não               NaN         NaN              0.0           0.0
# 9336         Sim            10.207  Prateleira            120.0           0.0
# 9337         Não               NaN         NaN              0.0           0.0
# 9338         Sim            10.566  Prateleira            100.0         108.0
#
# [9321 rows x 14 columns]

# %% [markdown]
# ## Juntando as informações

# %% [markdown]
# ### Fracionado

# %%
curva_abc_frac = pd.merge(curva_frac, produtos, on='Código', how='outer')

curva_abc_frac['Código'] = pd.to_numeric(curva_abc_frac['Código'])

curva_abc_frac['Ender.Fracionado'] = curva_abc_frac['Ender.Fracionado'].astype(str)

refatorar_indece(curva_abc_frac, 'Ordem')

curva_abc_frac
# Out:
#          Código Curva Frac  Qtde Venda Frac  Dias Pedido Frac  \
# Ordem
# 1      106011.0          A         327757.0             278.0
# 2      231012.0          A         179721.0             256.0
# 3      101190.0          A         163997.0             257.0
# 4      102011.0          A         110027.0             273.0
# 5      102133.0          A         104442.0             274.0
# ...         ...        ...              ...               ...
# 9327   316036.0        NaN              NaN               NaN
# 9328    11211.0        NaN              NaN               NaN
# 9329    29909.0        NaN              NaN               NaN
# 9330    29910.0        NaN              NaN               NaN
# 9331   420655.0        NaN              NaN               NaN
#
#        Média por dia frac  Ativ.Ressupr.Frac  Qtde Desvio Picking  \
# Ordem
# 1               1178.9820             1378.0               3399.0
# 2                702.0352             1076.0               2743.0
# 3                638.1206             1166.0               4703.0
# 4                403.0293              749.0               4942.0
# 5                381.1752              747.0               4575.0
# ...                   ...                ...                  ...
# 9327                  NaN                NaN                  NaN
# 9328                  NaN                NaN                  NaN
# 9329                  NaN                NaN                  NaN
# 9330                  NaN                NaN                  NaN
# 9331                  NaN                NaN                  NaN
#
#                                      Descrição  Estoque Armaz. Apanha Cx  \
# Ordem
# 1                  NARIDRIN 12 HORAS FR C/30ML          2307.0       Sim
# 2                      EXPEC XAROPE FR C/120ML          2134.0       Sim
# 3                        EMSEXPECTOR XPE 120ML           882.0       Sim
# 4                              CYSTEX C/ 24DRG           255.0       Sim
# 5         ALLEXOFEDRIN ( D) 60+120MG C/ 10COMP           601.0       Sim
# ...                                        ...             ...       ...
# 9327   ZOLPIDEM 10MG C/30 CPR (B1)** TEUTO-GEN             0.0       Sim
# 9328             ZOLPIDEM 10MG 10CP (B1)** GEN             0.0       Não
# 9329              ZOLPIDEM 10MG 10CP (B1)** NQ             0.0       Não
# 9330              ZOLPIDEM 10MG 20CP (B1)** NQ             0.0       Sim
# 9331            ZOLPIDEM 10MG 20CPR (B1)**EURO             0.0       Não
#
#       Permite Frac. Ender.Cx.Fechada  Embal.  Capacidade Cx Estoque Cx  \
# Ordem
# 1               Não    016-037-01-01   100.0            6.0         42
# 2               Não    016-043-01-02    60.0            5.0         38
# 3               Não    016-035-01-02    60.0            3.0         25
# 4               Não    014-022-02-02   100.0            8.0          1
# 5               Não    014-040-02-02    48.0           36.0         21
# ...             ...              ...     ...            ...        ...
# 9327            Não    018-004-01-02   100.0            2.0          0
# 9328            Não              NaN    60.0            0.0          0
# 9329            Não              NaN    60.0            0.0          0
# 9330            Não    018-006-01-01    60.0            3.0          0
# 9331            Não              NaN    36.0            0.0          0
#
#       Apanha Frac Ender.Fracionado        Tipo  Capacidade Frac  Estoque Frac
# Ordem
# 1             Sim           29.913  Ponta De G            200.0         172.0
# 2             Sim           18.015    Flowrack            414.0         208.0
# 3             Sim           29.911  Ponta De G            240.0         162.0
# 4             Sim           29.063    Flowrack            300.0         235.0
# 5             Sim           19.012    Flowrack            336.0         293.0
# ...           ...              ...         ...              ...           ...
# 9327          Não              nan         NaN              0.0           0.0
# 9328          Não              nan         NaN              0.0           0.0
# 9329          Não              nan         NaN              0.0           0.0
# 9330          Sim           10.207  Prateleira            120.0           0.0
# 9331          Não              nan         NaN              0.0           0.0
#
# [9331 rows x 20 columns]

# %% [markdown]
# ### Caixa Fechada

# %%
curva_abc_cx = pd.merge(curva_cx, produtos, on='Código', how='outer')

curva_abc_cx['Código'] = pd.to_numeric(curva_abc_cx['Código'])

curva_abc_cx['Ender.Fracionado'] = curva_abc_cx['Ender.Fracionado'].astype(str)

refatorar_indece(curva_abc_cx, 'Ordem')

curva_abc_cx
# Out:
#          Código Curva Cx  Qtde Venda Cx  Dias Pedido Cx  Média por dia cx  \
# Ordem
# 1       60342.0        A        10209.0           251.0           40.6733
# 2       60341.0        A         9792.0           252.0           38.8571
# 3       60321.0        A         9680.0           245.0           39.5102
# 4       60343.0        A         9323.0           252.0           36.9960
# 5       60320.0        A         8163.0           228.0           35.8026
# ...         ...      ...            ...             ...               ...
# 9355   316036.0      NaN            NaN             NaN               NaN
# 9356    11211.0      NaN            NaN             NaN               NaN
# 9357    29909.0      NaN            NaN             NaN               NaN
# 9358    29910.0      NaN            NaN             NaN               NaN
# 9359   420655.0      NaN            NaN             NaN               NaN
#
#        Ativ.Ressupr.Cx                                Descrição  \
# Ordem
# 1                 21.0             FD INF VIC BABY MEGA EG 3X70
# 2                 15.0             FD INF VIC BABY MEGA G 03X80
# 3                 17.0    FD INF MULTIFRAL SUPER JUMBO EG 03X70
# 4                 18.0            FD INF VIC BABY MEGA XXG 3X56
# 5                 23.0     FD INF MULTIFRAL SUPER JUMBO G 03X80
# ...                ...                                      ...
# 9355               NaN  ZOLPIDEM 10MG C/30 CPR (B1)** TEUTO-GEN
# 9356               NaN            ZOLPIDEM 10MG 10CP (B1)** GEN
# 9357               NaN             ZOLPIDEM 10MG 10CP (B1)** NQ
# 9358               NaN             ZOLPIDEM 10MG 20CP (B1)** NQ
# 9359               NaN           ZOLPIDEM 10MG 20CPR (B1)**EURO
#
#        Estoque Armaz. Apanha Cx Permite Frac. Ender.Cx.Fechada  Embal.  \
# Ordem
# 1              1713.0       Sim           Sim    018-023-00-02     3.0
# 2              1622.0       Sim           Sim    017-034-01-01     3.0
# 3                 0.0       Sim           Sim    018-027-01-01     3.0
# 4              1779.0       Sim           Sim    018-021-01-01     3.0
# 5                 0.0       Sim           Sim    018-029-00-02     3.0
# ...               ...       ...           ...              ...     ...
# 9355              0.0       Sim           Não    018-004-01-02   100.0
# 9356              0.0       Não           Não              NaN    60.0
# 9357              0.0       Não           Não              NaN    60.0
# 9358              0.0       Sim           Não    018-006-01-01    60.0
# 9359              0.0       Não           Não              NaN    36.0
#
#        Capacidade Cx  Estoque Cx Apanha Frac Ender.Fracionado        Tipo  \
# Ordem
# 1                7.0   9 (+2 fr)         Sim           29.223  Prateleira
# 2                1.0           3         Sim           29.221  Prateleira
# 3               10.0           0         Sim           29.512  Prateleira
# 4                5.0  13 (+2 fr)         Sim           29.575  Prateleira
# 5                2.0           0         Não              nan         NaN
# ...              ...         ...         ...              ...         ...
# 9355             2.0           0         Não              nan         NaN
# 9356             0.0           0         Não              nan         NaN
# 9357             0.0           0         Não              nan         NaN
# 9358             3.0           0         Sim           10.207  Prateleira
# 9359             0.0           0         Não              nan         NaN
#
#        Capacidade Frac  Estoque Frac
# Ordem
# 1                  8.0           8.0
# 2                  3.0           3.0
# 3                  8.0           0.0
# 4                  6.0           6.0
# 5                  0.0           0.0
# ...                ...           ...
# 9355               0.0           0.0
# 9356               0.0           0.0
# 9357               0.0           0.0
# 9358             120.0           0.0
# 9359               0.0           0.0
#
# [9359 rows x 19 columns]

# %% [markdown]
# ### Geral

# %%
curva_abc_geral = pd.merge(curva_geral, produtos, on='Código', how='outer')

curva_abc_geral['Código'] = pd.to_numeric(curva_abc_geral['Código'])

curva_abc_geral['Ender.Fracionado'] = curva_abc_geral['Ender.Fracionado'].astype(str)

refatorar_indece(curva_abc_geral, 'Ordem')

curva_abc_geral
# Out:
#          Código Curva Geral  Qtde Venda Geral  Dias Pedido Geral  \
# Ordem
# 1      106011.0           A         1072921.0              288.0
# 2      231012.0           A          500717.0              261.0
# 3      101190.0           A          291552.0              262.0
# 4      101175.0           A          174453.0              269.0
# 5       10302.0           A          171439.0              181.0
# ...         ...         ...               ...                ...
# 9335   421840.0         NaN               NaN                NaN
# 9336   316036.0         NaN               NaN                NaN
# 9337    11211.0         NaN               NaN                NaN
# 9338    29909.0         NaN               NaN                NaN
# 9339   420655.0         NaN               NaN                NaN
#
#        Média por dia geral  Ativ.Ressupr.Geral  \
# Ordem
# 1                3725.4201              1393.0
# 2                1918.4559              1076.0
# 3                1112.7939              1175.0
# 4                 648.5242               693.0
# 5                 947.1768               174.0
# ...                    ...                 ...
# 9335                   NaN                 NaN
# 9336                   NaN                 NaN
# 9337                   NaN                 NaN
# 9338                   NaN                 NaN
# 9339                   NaN                 NaN
#
#                                      Descrição  Estoque Armaz. Apanha Cx  \
# Ordem
# 1                  NARIDRIN 12 HORAS FR C/30ML          2307.0       Sim
# 2                      EXPEC XAROPE FR C/120ML          2134.0       Sim
# 3                        EMSEXPECTOR XPE 120ML           882.0       Sim
# 4                          INFRALAX C/ 15 COMP           453.0       Sim
# 5                      LOSARTANA POT 50MG 30CP             0.0       Sim
# ...                                        ...             ...       ...
# 9335      ZOLPIDEM  5MG (B1)** C/ 30 COMP SUBL             0.0       Sim
# 9336   ZOLPIDEM 10MG C/30 CPR (B1)** TEUTO-GEN             0.0       Sim
# 9337             ZOLPIDEM 10MG 10CP (B1)** GEN             0.0       Não
# 9338              ZOLPIDEM 10MG 10CP (B1)** NQ             0.0       Não
# 9339            ZOLPIDEM 10MG 20CPR (B1)**EURO             0.0       Não
#
#       Permite Frac. Ender.Cx.Fechada  Embal.  Capacidade Cx Estoque Cx  \
# Ordem
# 1               Não    016-037-01-01   100.0            6.0         42
# 2               Não    016-043-01-02    60.0            5.0         38
# 3               Não    016-035-01-02    60.0            3.0         25
# 4               Não    014-032-02-01    48.0           30.0         20
# 5               Não    015-033-01-01    84.0           25.0          0
# ...             ...              ...     ...            ...        ...
# 9335            Não    018-001-01-02    96.0            1.0          0
# 9336            Não    018-004-01-02   100.0            2.0          0
# 9337            Não              NaN    60.0            0.0          0
# 9338            Não              NaN    60.0            0.0          0
# 9339            Não              NaN    36.0            0.0          0
#
#       Apanha Frac Ender.Fracionado        Tipo  Capacidade Frac  Estoque Frac
# Ordem
# 1             Sim           29.913  Ponta De G            200.0         172.0
# 2             Sim           18.015    Flowrack            414.0         208.0
# 3             Sim           29.911  Ponta De G            240.0         162.0
# 4             Sim           20.083    Flowrack            192.0         160.0
# 5             Sim           22.013    Flowrack             84.0           0.0
# ...           ...              ...         ...              ...           ...
# 9335          Não              nan         NaN              0.0           0.0
# 9336          Não              nan         NaN              0.0           0.0
# 9337          Não              nan         NaN              0.0           0.0
# 9338          Não              nan         NaN              0.0           0.0
# 9339          Não              nan         NaN              0.0           0.0
#
# [9339 rows x 19 columns]

# %% [markdown]
# ### Situação Final

# %%
situacao_final = pd.merge(curva_geral, produtos, on='Código', how='outer')

situacao_final['Código'] = pd.to_numeric(situacao_final['Código'])

situacao_final['Ender.Fracionado'] = situacao_final['Ender.Fracionado'].astype(str)

# Juntando a curva geral com a cx fech e fracionada
curva_cx_final = curva_cx[['Código', 'Curva Cx', 'Qtde Venda Cx', 'Dias Pedido Cx', 'Média por dia cx', 'Ativ.Ressupr.Cx']]
curva_frac_final = curva_frac[['Código', 'Curva Frac', 'Qtde Venda Frac', 'Dias Pedido Frac', 'Média por dia frac', 'Ativ.Ressupr.Frac', 'Qtde Desvio Picking']]

situacao_final['Código'] = situacao_final['Código'].astype(str)
situacao_final = pd.merge(situacao_final, curva_cx_final, on='Código', how='outer')

situacao_final['Código'] = situacao_final['Código'].astype(str)
situacao_final = pd.merge(situacao_final, curva_frac_final, on='Código', how='outer')

situacao_final['Código'] = pd.to_numeric(situacao_final['Código'])

refatorar_indece(situacao_final, 'Ordem')

situacao_final
# Out:
#          Código Curva Geral  Qtde Venda Geral  Dias Pedido Geral  \
# Ordem
# 1      106011.0           A         1072921.0              288.0
# 2      231012.0           A          500717.0              261.0
# 3      101190.0           A          291552.0              262.0
# 4      101175.0           A          174453.0              269.0
# 5       10302.0           A          171439.0              181.0
# ...         ...         ...               ...                ...
# 9372   421840.0         NaN               NaN                NaN
# 9373   316036.0         NaN               NaN                NaN
# 9374    11211.0         NaN               NaN                NaN
# 9375    29909.0         NaN               NaN                NaN
# 9376   420655.0         NaN               NaN                NaN
#
#        Média por dia geral  Ativ.Ressupr.Geral  \
# Ordem
# 1                3725.4201              1393.0
# 2                1918.4559              1076.0
# 3                1112.7939              1175.0
# 4                 648.5242               693.0
# 5                 947.1768               174.0
# ...                    ...                 ...
# 9372                   NaN                 NaN
# 9373                   NaN                 NaN
# 9374                   NaN                 NaN
# 9375                   NaN                 NaN
# 9376                   NaN                 NaN
#
#                                      Descrição  Estoque Armaz. Apanha Cx  \
# Ordem
# 1                  NARIDRIN 12 HORAS FR C/30ML          2307.0       Sim
# 2                      EXPEC XAROPE FR C/120ML          2134.0       Sim
# 3                        EMSEXPECTOR XPE 120ML           882.0       Sim
# 4                          INFRALAX C/ 15 COMP           453.0       Sim
# 5                      LOSARTANA POT 50MG 30CP             0.0       Sim
# ...                                        ...             ...       ...
# 9372      ZOLPIDEM  5MG (B1)** C/ 30 COMP SUBL             0.0       Sim
# 9373   ZOLPIDEM 10MG C/30 CPR (B1)** TEUTO-GEN             0.0       Sim
# 9374             ZOLPIDEM 10MG 10CP (B1)** GEN             0.0       Não
# 9375              ZOLPIDEM 10MG 10CP (B1)** NQ             0.0       Não
# 9376            ZOLPIDEM 10MG 20CPR (B1)**EURO             0.0       Não
#
#       Permite Frac. Ender.Cx.Fechada  Embal.  Capacidade Cx Estoque Cx  \
# Ordem
# 1               Não    016-037-01-01   100.0            6.0         42
# 2               Não    016-043-01-02    60.0            5.0         38
# 3               Não    016-035-01-02    60.0            3.0         25
# 4               Não    014-032-02-01    48.0           30.0         20
# 5               Não    015-033-01-01    84.0           25.0          0
# ...             ...              ...     ...            ...        ...
# 9372            Não    018-001-01-02    96.0            1.0          0
# 9373            Não    018-004-01-02   100.0            2.0          0
# 9374            Não              NaN    60.0            0.0          0
# 9375            Não              NaN    60.0            0.0          0
# 9376            Não              NaN    36.0            0.0          0
#
#       Apanha Frac Ender.Fracionado        Tipo  Capacidade Frac  Estoque Frac  \
# Ordem
# 1             Sim           29.913  Ponta De G            200.0         172.0
# 2             Sim           18.015    Flowrack            414.0         208.0
# 3             Sim           29.911  Ponta De G            240.0         162.0
# 4             Sim           20.083    Flowrack            192.0         160.0
# 5             Sim           22.013    Flowrack             84.0           0.0
# ...           ...              ...         ...              ...           ...
# 9372          Não              nan         NaN              0.0           0.0
# 9373          Não              nan         NaN              0.0           0.0
# 9374          Não              nan         NaN              0.0           0.0
# 9375          Não              nan         NaN              0.0           0.0
# 9376          Não              nan         NaN              0.0           0.0
#
#       Curva Cx  Qtde Venda Cx  Dias Pedido Cx  Média por dia cx  \
# Ordem
# 1            A         7332.0           254.0           28.8661
# 2            A         5347.0           212.0           25.2217
# 3            A         1432.0           177.0            8.0904
# 4            A         1567.0           213.0            7.3568
# 5            A         1623.0           105.0           15.4571
# ...        ...            ...             ...               ...
# 9372       NaN            NaN             NaN               NaN
# 9373       NaN            NaN             NaN               NaN
# 9374       NaN            NaN             NaN               NaN
# 9375       NaN            NaN             NaN               NaN
# 9376       NaN            NaN             NaN               NaN
#
#        Ativ.Ressupr.Cx Curva Frac  Qtde Venda Frac  Dias Pedido Frac  \
# Ordem
# 1                318.0          A         327757.0             278.0
# 2                333.0          A         179721.0             256.0
# 3                357.0          A         163997.0             257.0
# 4                335.0          A          96488.0             261.0
# 5                167.0          A          34405.0             172.0
# ...                ...        ...              ...               ...
# 9372               NaN        NaN              NaN               NaN
# 9373               NaN        NaN              NaN               NaN
# 9374               NaN        NaN              NaN               NaN
# 9375               NaN        NaN              NaN               NaN
# 9376               NaN        NaN              NaN               NaN
#
#        Média por dia frac  Ativ.Ressupr.Frac  Qtde Desvio Picking
# Ordem
# 1               1178.9820             1378.0               3399.0
# 2                702.0352             1076.0               2743.0
# 3                638.1206             1166.0               4703.0
# 4                369.6858              678.0               2368.0
# 5                200.0291              169.0                123.0
# ...                   ...                ...                  ...
# 9372                  NaN                NaN                  NaN
# 9373                  NaN                NaN                  NaN
# 9374                  NaN                NaN                  NaN
# 9375                  NaN                NaN                  NaN
# 9376                  NaN                NaN                  NaN
#
# [9376 rows x 30 columns]

# %% [markdown]
# # Organizando colunas

# %%
# Organizar as colunas curva geral

curva_abc_geral = curva_abc_geral[['Código', 
                                   'Descrição', 
                                   'Curva Geral', 
                                   'Qtde Venda Geral', 
                                   'Dias Pedido Geral', 
                                   'Ativ.Ressupr.Geral',
                                   'Média por dia geral',
                                   'Estoque Armaz.',
                                   'Ender.Cx.Fechada',
                                   'Estoque Cx',
                                   'Capacidade Cx',
                                   'Embal.',
                                   'Permite Frac.',
                                   'Ender.Fracionado',
                                   'Capacidade Frac',
                                   'Estoque Frac',
                                   'Tipo',
                                  ]]

# Organizar as colunas curva frac

curva_abc_frac = curva_abc_frac[['Código', 
                                   'Descrição', 
                                   'Curva Frac', 
                                   'Qtde Venda Frac', 
                                   'Dias Pedido Frac', 
                                   'Ativ.Ressupr.Frac',
                                   'Média por dia frac',
                                   'Qtde Desvio Picking'
                                  ]]

# Organizar as colunas curva cx

curva_abc_cx = curva_abc_cx[['Código', 
                                   'Descrição', 
                                   'Curva Cx', 
                                   'Qtde Venda Cx', 
                                   'Dias Pedido Cx', 
                                   'Ativ.Ressupr.Cx',
                                   'Média por dia cx',
                                   'Permite Frac.',
                                  ]]

# Organizar as colunas da situacao final

situacao_final = situacao_final[['Código', 
                                   'Descrição', 
                                   'Curva Frac',
                                   'Curva Cx',
                                   'Curva Geral', 
                                   'Qtde Venda Frac', 
                                   'Qtde Venda Cx', 
                                   'Qtde Venda Geral', 
                                   'Dias Pedido Frac', 
                                   'Dias Pedido Cx', 
                                   'Dias Pedido Geral', 
                                   'Ativ.Ressupr.Frac',
                                   'Ativ.Ressupr.Cx',
                                   'Ativ.Ressupr.Geral',
                                   'Média por dia frac',
                                   'Média por dia cx',
                                   'Média por dia geral',
                                   'Estoque Armaz.',
                                   'Ender.Cx.Fechada',
                                   'Estoque Frac',
                                   'Capacidade Frac',
                                   'Embal.',
                                   'Permite Frac.',
                                   'Apanha Frac',
                                   'Ender.Fracionado',
                                   'Tipo',
                                   'Qtde Desvio Picking',
                                ]]

# %% [markdown]
# ### Tratando NaN

# %%
curva_abc_geral['Descrição'] = curva_abc_geral['Descrição'].fillna('-')

curva_abc_cx['Descrição'] = curva_abc_cx['Descrição'].fillna('-')

curva_abc_frac['Descrição'] = curva_abc_frac['Descrição'].fillna('-')

situacao_final['Descrição'] = situacao_final['Descrição'].fillna('-')
# Out:
# C:\Users\estoque\AppData\Local\Temp\ipykernel_9976\57950684.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   curva_abc_geral['Descrição'] = curva_abc_geral['Descrição'].fillna('-')
# C:\Users\estoque\AppData\Local\Temp\ipykernel_9976\57950684.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   curva_abc_cx['Descrição'] = curva_abc_cx['Descrição'].fillna('-')
# C:\Users\estoque\AppData\Local\Temp\ipykernel_9976\57950684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   curva_abc_frac['Descrição'] = curva_abc_frac['Descrição'].fillna('-')
# C:\Users\estoque\AppData\Local\Temp\ipykernel_9976\57950684.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   situacao_final['Descrição'] = situacao_final['Descrição'].fillna('-')

# %%
curva_abc_geral.to_excel('dados_tratados\curva_abc_geral.xlsx')
curva_abc_frac.to_excel('dados_tratados\curva_abc_frac.xlsx')
curva_abc_cx.to_excel('dados_tratados\curva_abc_cx.xlsx')
situacao_final.to_excel('dados_tratados\situacao_final.xlsx')
