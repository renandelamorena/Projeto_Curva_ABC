# %% [markdown]
# # Importando Bibliotecas

# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %% [markdown]
# # Importando Dados

# %%
produtos = pd.read_excel(r'C:\Users\estoque\Documents\estoque.renan\projetos\projeto_curva_abc\tratamento_curva_abc\datasets\produtos.xlsx')

# %%
curva_geral = pd.read_excel(r'C:\Users\estoque\Documents\estoque.renan\projetos\projeto_curva_abc\tratamento_curva_abc\datasets\curva_geral.xlsx')

# %%
curva_cx = pd.read_excel(r'C:\Users\estoque\Documents\estoque.renan\projetos\projeto_curva_abc\tratamento_curva_abc\datasets\curva_cx.xlsx')

# %%
curva_frac = pd.read_excel(r'C:\Users\estoque\Documents\estoque.renan\projetos\projeto_curva_abc\tratamento_curva_abc\datasets\curva_frac.xlsx')

# %% [markdown]
# # Tratando Dados

# %% [markdown]
# # Funções

# %%
def tratar_codigos(dfs):
    
    for df in dfs:
        
        df['Código'] = df['Código'].astype(str)

        df['Código'] = df['Código'].str.slice(start=2)
        df['Código'] = df['Código'].str.lstrip('0')

    return df

# %%
def refatorar_indece(df, nome_index):
    
    qnt_linha = df.shape[0] + 1

    index = [i for i in range(1, qnt_linha)]

    df.set_index(pd.Index(index), inplace=True)

    df.index.name = nome_index
    
    return df

# %%
def procurar(df, coluna, oque):
    
    selecao = df[coluna] == oque
    
    return df[selecao]

# %% [markdown]
# ## Tratamento cadastro produtos

# %%
# Excluir linhas vazias
produtos = produtos.dropna(how='all')

# Selecionando somente as principais colunas
produtos = produtos[['Código',
                     'Descrição',
                     'Estoque Armaz.',
                     'Apanha',
                     'Permite Frac.',
                     'Ender.Cx.Fechada',
                     'Embal.',
                     'Capacidade',
                     'Estoque',
                     'Apanha.1',
                     'Ender.Fracionado',
                     'Tipo',
                     'Capacidade.1',
                     'Estoque.1'
                    ]]

# Renomear colunas de geral
renomear_produtos = {'Apanha.1' : 'Apanha Frac',
                    'Apanha' : 'Apanha Cx',
                    'Capacidade.1' : 'Capacidade Frac',
                    'Capacidade' : 'Capacidade Cx',
                    'Estoque.1' : 'Estoque Frac',
                    'Estoque' : 'Estoque Cx'
                   }

produtos.rename(columns = renomear_produtos, inplace = True)

# %% [markdown]
#  ## Tratamento Curvas

# %% [markdown]
# ### Geral

# %%
# Excluir linhas vazias
curva_geral = curva_geral.dropna(how='all')

# Selecionando somente as principais colunas
curva_geral = curva_geral[['Cód.Produto', 'Curva', 'Qtde Venda', 'Dias Pedido', 'Média por dia', 'Ativ.Ressupr.']]

# Renomear colunas de geral
renomear_geral = {'Cód.Produto' : 'Código',
                   'Curva' : 'Curva Geral',
                   'Qtde Venda' : 'Qtde Venda Geral',
                   'Dias Pedido' : 'Dias Pedido Geral',
                   'Média por dia' : 'Média por dia geral',
                   'Ativ.Ressupr.' : 'Ativ.Ressupr.Geral',
                  }

curva_geral.rename(columns = renomear_geral, inplace = True)

# %% [markdown]
# ### Fracionado

# %%
# Excluir linhas vazias
curva_frac = curva_frac.dropna(how='all')

# Selecionando somente as principais colunas
curva_frac = curva_frac[['Cód.Produto', 'Curva', 'Qtde Venda', 'Dias Pedido', 'Média por dia', 'Ativ.Ressupr.', 'Qtde Desvio Picking']]

# Renomear colunas de frac
renomear_frac = {'Cód.Produto' : 'Código',
               'Curva' : 'Curva Frac',
               'Qtde Venda' : 'Qtde Venda Frac',
               'Dias Pedido' : 'Dias Pedido Frac',
               'Média por dia' : 'Média por dia frac',
               'Ativ.Ressupr.' : 'Ativ.Ressupr.Frac',
              }

curva_frac.rename(columns = renomear_frac, inplace = True)

# %% [markdown]
# ### Caixa Fechada

# %%
# Excluir linhas vazias
curva_cx = curva_cx.dropna(how='all')

# Selecionando somente as principais colunas
curva_cx = curva_cx[['Cód.Produto', 'Curva', 'Qtde Venda', 'Dias Pedido', 'Média por dia', 'Ativ.Ressupr.']]

# Renomear colunas de cx
renomear_cx = {'Cód.Produto' : 'Código',
               'Curva' : 'Curva Cx',
               'Qtde Venda' : 'Qtde Venda Cx',
               'Dias Pedido' : 'Dias Pedido Cx',
               'Média por dia' : 'Média por dia cx',
               'Ativ.Ressupr.' : 'Ativ.Ressupr.Cx',
              }

curva_cx.rename(columns = renomear_cx, inplace = True)

# %% [markdown]
# ## Tratando códigos

# %%
dfs = [curva_geral, curva_frac, curva_cx, produtos]
tratar_codigos(dfs)
# Out:
#         Código                            Descrição  Estoque Armaz. Apanha Cx  \
# 0     460000.0              A SAUDE DA MULHER 150ML             0.0       Sim
# 1      10531.0                 AAS 100MG C/ 100COMP             0.0       Sim
# 2      10424.0                 AAS 100MG C/ 200COMP             0.0       Sim
# 3      10425.0                  AAS 100MG C/ 30COMP            48.0       Sim
# 4      10159.0                 AAS 500MG C/ 200COMP             0.0       Sim
# ...        ...                                  ...             ...       ...
# 9333   11211.0        ZOLPIDEM 10MG 10CP (B1)** GEN             0.0       Sim
# 9334   29909.0         ZOLPIDEM 10MG 10CP (B1)** NQ             0.0       Não
# 9335   29910.0         ZOLPIDEM 10MG 20CP (B1)** NQ             0.0       Sim
# 9336  420655.0       ZOLPIDEM 10MG 20CPR (B1)**EURO             0.0       Sim
# 9337   16361.0  ZOLPIDEM 5MG (B1)** C/ 30 COMP SUBL             5.0       Sim
#
#      Permite Frac. Ender.Cx.Fechada  Embal.  Capacidade Cx  Estoque Cx  \
# 0              Não    014-026-01-02    35.0            3.0           0
# 1              Sim    010-014-01-02    40.0            2.0  1 (+18 fr)
# 2              Não    016-013-01-02    40.0            3.0           3
# 3              Não    015-027-01-02    84.0           10.0           6
# 4              Não    014-010-01-02    24.0            3.0           0
# ...            ...              ...     ...            ...         ...
# 9333           Não    018-001-01-01    60.0            2.0           0
# 9334           Não              NaN    60.0            0.0           0
# 9335           Não    018-006-01-01    60.0            3.0           0
# 9336           Não    018-003-01-01    36.0            4.0           0
# 9337           Não    018-001-01-02   100.0            1.0           1
#
#      Apanha Frac  Ender.Fracionado        Tipo  Capacidade Frac  Estoque Frac
# 0            Sim            24.071    Flowrack             60.0           0.0
# 1            Sim            26.144  Prateleira             41.0          30.0
# 2            Sim            25.086    Flowrack            200.0         152.0
# 3            Sim            26.022    Flowrack            252.0         334.0
# 4            Não               NaN         NaN              0.0           0.0
# ...          ...               ...         ...              ...           ...
# 9333         Sim            11.103  Prateleira            120.0           0.0
# 9334         Não               NaN         NaN              0.0           0.0
# 9335         Sim            10.207  Prateleira            120.0           0.0
# 9336         Sim            11.144  Prateleira             36.0           0.0
# 9337         Sim            11.528  Prateleira            100.0         154.0
#
# [9320 rows x 14 columns]

# %% [markdown]
# ## Juntando as informações

# %% [markdown]
# ### Fracionado

# %%
curva_abc_frac = pd.merge(curva_frac, produtos, on='Código', how='outer')

curva_abc_frac['Código'] = pd.to_numeric(curva_abc_frac['Código'])

curva_abc_frac['Ender.Fracionado'] = curva_abc_frac['Ender.Fracionado'].astype(str)

refatorar_indece(curva_abc_frac, 'Ordem')

curva_abc_frac
# Out:
#          Código Curva Frac  Qtde Venda Frac  Dias Pedido Frac  \
# Ordem
# 1      106011.0          A         358262.0             285.0
# 2      101190.0          A         210821.0             249.0
# 3      231012.0          A         202491.0             255.0
# 4      102133.0          A         113290.0             279.0
# 5      102011.0          A         111651.0             283.0
# ...         ...        ...              ...               ...
# 9335   421840.0        NaN              NaN               NaN
# 9336   316036.0        NaN              NaN               NaN
# 9337    11211.0        NaN              NaN               NaN
# 9338    29909.0        NaN              NaN               NaN
# 9339   420655.0        NaN              NaN               NaN
#
#        Média por dia frac  Ativ.Ressupr.Frac  Qtde Desvio Picking  \
# Ordem
# 1               1257.0596             1354.0               4501.0
# 2                846.6707             1109.0               7197.0
# 3                794.0824             1010.0               3382.0
# 4                406.0573              752.0               6424.0
# 5                394.5265              739.0               6183.0
# ...                   ...                ...                  ...
# 9335                  NaN                NaN                  NaN
# 9336                  NaN                NaN                  NaN
# 9337                  NaN                NaN                  NaN
# 9338                  NaN                NaN                  NaN
# 9339                  NaN                NaN                  NaN
#
#                                      Descrição  Estoque Armaz. Apanha Cx  \
# Ordem
# 1                  NARIDRIN 12 HORAS FR C/30ML          2469.0       Sim
# 2                        EMSEXPECTOR XPE 120ML           938.0       Sim
# 3                      EXPEC XAROPE FR C/120ML          2335.0       Sim
# 4         ALLEXOFEDRIN ( D) 60+120MG C/ 10COMP           636.0       Sim
# 5                              CYSTEX C/ 24DRG           283.0       Sim
# ...                                        ...             ...       ...
# 9335      ZOLPIDEM  5MG (B1)** C/ 30 COMP SUBL             0.0       Sim
# 9336   ZOLPIDEM 10MG C/30 CPR (B1)** TEUTO-GEN             0.0       Sim
# 9337             ZOLPIDEM 10MG 10CP (B1)** GEN             0.0       Sim
# 9338              ZOLPIDEM 10MG 10CP (B1)** NQ             0.0       Não
# 9339            ZOLPIDEM 10MG 20CPR (B1)**EURO             0.0       Sim
#
#       Permite Frac. Ender.Cx.Fechada  Embal.  Capacidade Cx Estoque Cx  \
# Ordem
# 1               Não    016-037-01-01   100.0            6.0         37
# 2               Não    016-035-01-02    60.0            3.0         33
# 3               Não    016-043-01-02    60.0            5.0          7
# 4               Não    014-040-02-02    48.0           36.0         36
# 5               Não    014-022-02-02   100.0            8.0          8
# ...             ...              ...     ...            ...        ...
# 9335            Não    018-001-01-02    96.0            1.0          0
# 9336            Não    018-004-01-02   100.0            2.0          0
# 9337            Não    018-001-01-01    60.0            2.0          0
# 9338            Não              NaN    60.0            0.0          0
# 9339            Não    018-003-01-01    36.0            4.0          0
#
#       Apanha Frac Ender.Fracionado        Tipo  Capacidade Frac  Estoque Frac
# Ordem
# 1             Sim           29.913  Ponta De G            200.0         261.0
# 2             Sim           29.911  Ponta De G            240.0         155.0
# 3             Sim           18.015    Flowrack            240.0         230.0
# 4             Sim           29.033    Flowrack            336.0         288.0
# 5             Sim           29.063    Flowrack            300.0         245.0
# ...           ...              ...         ...              ...           ...
# 9335          Não              nan         NaN              0.0           0.0
# 9336          Não              nan         NaN              0.0           0.0
# 9337          Sim           11.103  Prateleira            120.0           0.0
# 9338          Não              nan         NaN              0.0           0.0
# 9339          Sim           11.144  Prateleira             36.0           0.0
#
# [9339 rows x 20 columns]

# %% [markdown]
# ### Caixa Fechada

# %%
curva_abc_cx = pd.merge(curva_cx, produtos, on='Código', how='outer')

curva_abc_cx['Código'] = pd.to_numeric(curva_abc_cx['Código'])

curva_abc_cx['Ender.Fracionado'] = curva_abc_cx['Ender.Fracionado'].astype(str)

refatorar_indece(curva_abc_cx, 'Ordem')

curva_abc_cx
# Out:
#          Código Curva Cx  Qtde Venda Cx  Dias Pedido Cx  Média por dia cx  \
# Ordem
# 1       60342.0        A        10294.0           251.0           41.0120
# 2       60321.0        A         9960.0           247.0           40.3239
# 3       60341.0        A         9816.0           251.0           39.1076
# 4       60343.0        A         9329.0           252.0           37.0198
# 5       60320.0        A         8658.0           242.0           35.7769
# ...         ...      ...            ...             ...               ...
# 9351   316036.0      NaN            NaN             NaN               NaN
# 9352    11211.0      NaN            NaN             NaN               NaN
# 9353    29909.0      NaN            NaN             NaN               NaN
# 9354    29910.0      NaN            NaN             NaN               NaN
# 9355   420655.0      NaN            NaN             NaN               NaN
#
#        Ativ.Ressupr.Cx                                Descrição  \
# Ordem
# 1                 21.0             FD INF VIC BABY MEGA EG 3X70
# 2                 17.0    FD INF MULTIFRAL SUPER JUMBO EG 03X70
# 3                 13.0             FD INF VIC BABY MEGA G 03X80
# 4                 18.0            FD INF VIC BABY MEGA XXG 3X56
# 5                 20.0     FD INF MULTIFRAL SUPER JUMBO G 03X80
# ...                ...                                      ...
# 9351               NaN  ZOLPIDEM 10MG C/30 CPR (B1)** TEUTO-GEN
# 9352               NaN            ZOLPIDEM 10MG 10CP (B1)** GEN
# 9353               NaN             ZOLPIDEM 10MG 10CP (B1)** NQ
# 9354               NaN             ZOLPIDEM 10MG 20CP (B1)** NQ
# 9355               NaN           ZOLPIDEM 10MG 20CPR (B1)**EURO
#
#        Estoque Armaz. Apanha Cx Permite Frac. Ender.Cx.Fechada  Embal.  \
# Ordem
# 1              1919.0       Sim           Sim    018-023-00-02     3.0
# 2               128.0       Sim           Sim    018-027-01-01     3.0
# 3              1815.0       Sim           Sim    017-034-01-01     3.0
# 4              1974.0       Sim           Sim    018-021-01-01     3.0
# 5                 0.0       Sim           Sim    018-029-00-02     3.0
# ...               ...       ...           ...              ...     ...
# 9351              0.0       Sim           Não    018-004-01-02   100.0
# 9352              0.0       Sim           Não    018-001-01-01    60.0
# 9353              0.0       Não           Não              NaN    60.0
# 9354              0.0       Sim           Não    018-006-01-01    60.0
# 9355              0.0       Sim           Não    018-003-01-01    36.0
#
#        Capacidade Cx Estoque Cx Apanha Frac Ender.Fracionado        Tipo  \
# Ordem
# 1                7.0         12         Sim           29.286  Prateleira
# 2                3.0  9 (+2 fr)         Sim           29.762  Prateleira
# 3                1.0  5 (+1 fr)         Sim           29.221  Prateleira
# 4                5.0         16         Sim           29.288  Prateleira
# 5                2.0          0         Não              nan         NaN
# ...              ...        ...         ...              ...         ...
# 9351             2.0          0         Não              nan         NaN
# 9352             2.0          0         Sim           11.103  Prateleira
# 9353             0.0          0         Não              nan         NaN
# 9354             3.0          0         Sim           10.207  Prateleira
# 9355             4.0          0         Sim           11.144  Prateleira
#
#        Capacidade Frac  Estoque Frac
# Ordem
# 1                  8.0           6.0
# 2                  8.0           3.0
# 3                  3.0           3.0
# 4                  6.0           9.0
# 5                  0.0           0.0
# ...                ...           ...
# 9351               0.0           0.0
# 9352             120.0           0.0
# 9353               0.0           0.0
# 9354             120.0           0.0
# 9355              36.0           0.0
#
# [9355 rows x 19 columns]

# %% [markdown]
# ### Geral

# %%
curva_abc_geral = pd.merge(curva_geral, produtos, on='Código', how='outer')

curva_abc_geral['Código'] = pd.to_numeric(curva_abc_geral['Código'])

curva_abc_geral['Ender.Fracionado'] = curva_abc_geral['Ender.Fracionado'].astype(str)

refatorar_indece(curva_abc_geral, 'Ordem')

curva_abc_geral
# Out:
#          Código Curva Geral  Qtde Venda Geral  Dias Pedido Geral  \
# Ordem
# 1      106011.0           A         1072921.0              288.0
# 2      231012.0           A          500717.0              261.0
# 3      101190.0           A          291552.0              262.0
# 4      101175.0           A          174453.0              269.0
# 5       10302.0           A          171439.0              181.0
# ...         ...         ...               ...                ...
# 9334   421840.0         NaN               NaN                NaN
# 9335   316036.0         NaN               NaN                NaN
# 9336    11211.0         NaN               NaN                NaN
# 9337    29909.0         NaN               NaN                NaN
# 9338   420655.0         NaN               NaN                NaN
#
#        Média por dia geral  Ativ.Ressupr.Geral  \
# Ordem
# 1                3725.4201              1393.0
# 2                1918.4559              1076.0
# 3                1112.7939              1175.0
# 4                 648.5242               693.0
# 5                 947.1768               174.0
# ...                    ...                 ...
# 9334                   NaN                 NaN
# 9335                   NaN                 NaN
# 9336                   NaN                 NaN
# 9337                   NaN                 NaN
# 9338                   NaN                 NaN
#
#                                      Descrição  Estoque Armaz. Apanha Cx  \
# Ordem
# 1                  NARIDRIN 12 HORAS FR C/30ML          2469.0       Sim
# 2                      EXPEC XAROPE FR C/120ML          2335.0       Sim
# 3                        EMSEXPECTOR XPE 120ML           938.0       Sim
# 4                          INFRALAX C/ 15 COMP           499.0       Sim
# 5                      LOSARTANA POT 50MG 30CP             0.0       Sim
# ...                                        ...             ...       ...
# 9334      ZOLPIDEM  5MG (B1)** C/ 30 COMP SUBL             0.0       Sim
# 9335   ZOLPIDEM 10MG C/30 CPR (B1)** TEUTO-GEN             0.0       Sim
# 9336             ZOLPIDEM 10MG 10CP (B1)** GEN             0.0       Sim
# 9337              ZOLPIDEM 10MG 10CP (B1)** NQ             0.0       Não
# 9338            ZOLPIDEM 10MG 20CPR (B1)**EURO             0.0       Sim
#
#       Permite Frac. Ender.Cx.Fechada  Embal.  Capacidade Cx Estoque Cx  \
# Ordem
# 1               Não    016-037-01-01   100.0            6.0         37
# 2               Não    016-043-01-02    60.0            5.0          7
# 3               Não    016-035-01-02    60.0            3.0         33
# 4               Não    014-032-02-01    48.0           30.0         30
# 5               Não    015-033-01-01    84.0           25.0          0
# ...             ...              ...     ...            ...        ...
# 9334            Não    018-001-01-02    96.0            1.0          0
# 9335            Não    018-004-01-02   100.0            2.0          0
# 9336            Não    018-001-01-01    60.0            2.0          0
# 9337            Não              NaN    60.0            0.0          0
# 9338            Não    018-003-01-01    36.0            4.0          0
#
#       Apanha Frac Ender.Fracionado        Tipo  Capacidade Frac  Estoque Frac
# Ordem
# 1             Sim           29.913  Ponta De G            200.0         261.0
# 2             Sim           18.015    Flowrack            240.0         230.0
# 3             Sim           29.911  Ponta De G            240.0         155.0
# 4             Sim           25.064    Flowrack            336.0         267.0
# 5             Não              nan         NaN              0.0           0.0
# ...           ...              ...         ...              ...           ...
# 9334          Não              nan         NaN              0.0           0.0
# 9335          Não              nan         NaN              0.0           0.0
# 9336          Sim           11.103  Prateleira            120.0           0.0
# 9337          Não              nan         NaN              0.0           0.0
# 9338          Sim           11.144  Prateleira             36.0           0.0
#
# [9338 rows x 19 columns]

# %% [markdown]
# ### Situação Final

# %%
situacao_final = pd.merge(curva_geral, produtos, on='Código', how='outer')

situacao_final['Código'] = pd.to_numeric(situacao_final['Código'])

situacao_final['Ender.Fracionado'] = situacao_final['Ender.Fracionado'].astype(str)

# Juntando a curva geral com a cx fech e fracionada
curva_cx_final = curva_cx[['Código', 'Curva Cx', 'Qtde Venda Cx', 'Dias Pedido Cx', 'Média por dia cx', 'Ativ.Ressupr.Cx']]
curva_frac_final = curva_frac[['Código', 'Curva Frac', 'Qtde Venda Frac', 'Dias Pedido Frac', 'Média por dia frac', 'Ativ.Ressupr.Frac', 'Qtde Desvio Picking']]

situacao_final['Código'] = situacao_final['Código'].astype(str)
situacao_final = pd.merge(situacao_final, curva_cx_final, on='Código', how='outer')

situacao_final['Código'] = situacao_final['Código'].astype(str)
situacao_final = pd.merge(situacao_final, curva_frac_final, on='Código', how='outer')

situacao_final['Código'] = pd.to_numeric(situacao_final['Código'])

refatorar_indece(situacao_final, 'Ordem')

situacao_final
# Out:
#          Código Curva Geral  Qtde Venda Geral  Dias Pedido Geral  \
# Ordem
# 1      106011.0           A         1072921.0              288.0
# 2      231012.0           A          500717.0              261.0
# 3      101190.0           A          291552.0              262.0
# 4      101175.0           A          174453.0              269.0
# 5       10302.0           A          171439.0              181.0
# ...         ...         ...               ...                ...
# 9369   316036.0         NaN               NaN                NaN
# 9370    11211.0         NaN               NaN                NaN
# 9371    29909.0         NaN               NaN                NaN
# 9372   420655.0         NaN               NaN                NaN
# 9373    61807.0         NaN               NaN                NaN
#
#        Média por dia geral  Ativ.Ressupr.Geral  \
# Ordem
# 1                3725.4201              1393.0
# 2                1918.4559              1076.0
# 3                1112.7939              1175.0
# 4                 648.5242               693.0
# 5                 947.1768               174.0
# ...                    ...                 ...
# 9369                   NaN                 NaN
# 9370                   NaN                 NaN
# 9371                   NaN                 NaN
# 9372                   NaN                 NaN
# 9373                   NaN                 NaN
#
#                                      Descrição  Estoque Armaz. Apanha Cx  \
# Ordem
# 1                  NARIDRIN 12 HORAS FR C/30ML          2469.0       Sim
# 2                      EXPEC XAROPE FR C/120ML          2335.0       Sim
# 3                        EMSEXPECTOR XPE 120ML           938.0       Sim
# 4                          INFRALAX C/ 15 COMP           499.0       Sim
# 5                      LOSARTANA POT 50MG 30CP             0.0       Sim
# ...                                        ...             ...       ...
# 9369   ZOLPIDEM 10MG C/30 CPR (B1)** TEUTO-GEN             0.0       Sim
# 9370             ZOLPIDEM 10MG 10CP (B1)** GEN             0.0       Sim
# 9371              ZOLPIDEM 10MG 10CP (B1)** NQ             0.0       Não
# 9372            ZOLPIDEM 10MG 20CPR (B1)**EURO             0.0       Sim
# 9373                                       NaN             NaN       NaN
#
#       Permite Frac. Ender.Cx.Fechada  Embal.  Capacidade Cx Estoque Cx  \
# Ordem
# 1               Não    016-037-01-01   100.0            6.0         37
# 2               Não    016-043-01-02    60.0            5.0          7
# 3               Não    016-035-01-02    60.0            3.0         33
# 4               Não    014-032-02-01    48.0           30.0         30
# 5               Não    015-033-01-01    84.0           25.0          0
# ...             ...              ...     ...            ...        ...
# 9369            Não    018-004-01-02   100.0            2.0          0
# 9370            Não    018-001-01-01    60.0            2.0          0
# 9371            Não              NaN    60.0            0.0          0
# 9372            Não    018-003-01-01    36.0            4.0          0
# 9373            NaN              NaN     NaN            NaN        NaN
#
#       Apanha Frac Ender.Fracionado        Tipo  Capacidade Frac  Estoque Frac  \
# Ordem
# 1             Sim           29.913  Ponta De G            200.0         261.0
# 2             Sim           18.015    Flowrack            240.0         230.0
# 3             Sim           29.911  Ponta De G            240.0         155.0
# 4             Sim           25.064    Flowrack            336.0         267.0
# 5             Não              nan         NaN              0.0           0.0
# ...           ...              ...         ...              ...           ...
# 9369          Não              nan         NaN              0.0           0.0
# 9370          Sim           11.103  Prateleira            120.0           0.0
# 9371          Não              nan         NaN              0.0           0.0
# 9372          Sim           11.144  Prateleira             36.0           0.0
# 9373          NaN              NaN         NaN              NaN           NaN
#
#       Curva Cx  Qtde Venda Cx  Dias Pedido Cx  Média por dia cx  \
# Ordem
# 1            A         7626.0           253.0           30.1423
# 2            A         5217.0           203.0           25.6995
# 3            A         1424.0           168.0            8.4762
# 4            A         1644.0           218.0            7.5413
# 5            A         1652.0           111.0           14.8829
# ...        ...            ...             ...               ...
# 9369       NaN            NaN             NaN               NaN
# 9370       NaN            NaN             NaN               NaN
# 9371       NaN            NaN             NaN               NaN
# 9372       NaN            NaN             NaN               NaN
# 9373       NaN            NaN             NaN               NaN
#
#        Ativ.Ressupr.Cx Curva Frac  Qtde Venda Frac  Dias Pedido Frac  \
# Ordem
# 1                341.0          A         358262.0             285.0
# 2                334.0          A         202491.0             255.0
# 3                356.0          A         210821.0             249.0
# 4                347.0          A         102083.0             272.0
# 5                178.0          A          36587.0             189.0
# ...                ...        ...              ...               ...
# 9369               NaN        NaN              NaN               NaN
# 9370               NaN        NaN              NaN               NaN
# 9371               NaN        NaN              NaN               NaN
# 9372               NaN        NaN              NaN               NaN
# 9373               NaN          C             14.0               2.0
#
#        Média por dia frac  Ativ.Ressupr.Frac  Qtde Desvio Picking
# Ordem
# 1               1257.0596             1354.0               4501.0
# 2                794.0824             1010.0               3382.0
# 3                846.6707             1109.0               7197.0
# 4                375.3051              714.0               3433.0
# 5                193.5820              186.0                128.0
# ...                   ...                ...                  ...
# 9369                  NaN                NaN                  NaN
# 9370                  NaN                NaN                  NaN
# 9371                  NaN                NaN                  NaN
# 9372                  NaN                NaN                  NaN
# 9373               7.0000                2.0                  0.0
#
# [9373 rows x 30 columns]

# %% [markdown]
# # Organizando colunas

# %%
# Organizar as colunas curva geral

curva_abc_geral = curva_abc_geral[['Código', 
                                   'Descrição', 
                                   'Curva Geral', 
                                   'Qtde Venda Geral', 
                                   'Dias Pedido Geral', 
                                   'Ativ.Ressupr.Geral',
                                   'Média por dia geral',
                                   'Estoque Armaz.',
                                   'Apanha Cx',
                                   'Ender.Cx.Fechada',
                                   'Estoque Cx',
                                   'Capacidade Cx',
                                   'Embal.',
                                   'Permite Frac.',
                                   'Apanha Frac',
                                   'Ender.Fracionado',
                                   'Capacidade Frac',
                                   'Estoque Frac',
                                   'Tipo',
                                  ]]

# Organizar as colunas curva frac

curva_abc_frac = curva_abc_frac[['Código', 
                                   'Descrição', 
                                   'Curva Frac', 
                                   'Qtde Venda Frac', 
                                   'Dias Pedido Frac', 
                                   'Ativ.Ressupr.Frac',
                                   'Média por dia frac',
                                   'Estoque Armaz.',
                                   'Apanha Frac',
                                   'Ender.Cx.Fechada',
                                   'Estoque Frac',
                                   'Embal.',
                                   'Ender.Fracionado',
                                   'Capacidade Frac',
                                   'Tipo',
                                   'Qtde Desvio Picking'
                                  ]]

# Organizar as colunas curva cx

curva_abc_cx = curva_abc_cx[['Código', 
                                   'Descrição', 
                                   'Curva Cx', 
                                   'Qtde Venda Cx', 
                                   'Dias Pedido Cx', 
                                   'Ativ.Ressupr.Cx',
                                   'Média por dia cx',
                                   'Estoque Armaz.',
                                   'Ender.Cx.Fechada',
                                   'Estoque Frac',
                                   'Capacidade Frac',
                                   'Embal.',
                                   'Permite Frac.',
                                   'Apanha Frac',
                                   'Ender.Fracionado',
                                   'Tipo',
                                  ]]

# Organizar as colunas da situacao final

situacao_final = situacao_final[['Código', 
                                   'Descrição', 
                                   'Curva Frac',
                                   'Curva Cx',
                                   'Curva Geral', 
                                   'Qtde Venda Frac', 
                                   'Qtde Venda Cx', 
                                   'Qtde Venda Geral', 
                                   'Dias Pedido Frac', 
                                   'Dias Pedido Cx', 
                                   'Dias Pedido Geral', 
                                   'Ativ.Ressupr.Frac',
                                   'Ativ.Ressupr.Cx',
                                   'Ativ.Ressupr.Geral',
                                   'Média por dia frac',
                                   'Média por dia cx',
                                   'Média por dia geral',
                                   'Estoque Armaz.',
                                   'Ender.Cx.Fechada',
                                   'Estoque Frac',
                                   'Capacidade Frac',
                                   'Embal.',
                                   'Permite Frac.',
                                   'Apanha Frac',
                                   'Ender.Fracionado',
                                   'Tipo',
                                   'Qtde Desvio Picking',
                                ]]

# %% [markdown]
# ### Tratando NaN

# %%
curva_abc_geral['Descrição'] = curva_abc_geral['Descrição'].fillna('-')

curva_abc_cx['Descrição'] = curva_abc_cx['Descrição'].fillna('-')

curva_abc_frac['Descrição'] = curva_abc_frac['Descrição'].fillna('-')

situacao_final['Descrição'] = situacao_final['Descrição'].fillna('-')
# Out:
# C:\Users\estoque\AppData\Local\Temp\ipykernel_28316\57950684.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   curva_abc_cx['Descrição'] = curva_abc_cx['Descrição'].fillna('-')
# C:\Users\estoque\AppData\Local\Temp\ipykernel_28316\57950684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   curva_abc_frac['Descrição'] = curva_abc_frac['Descrição'].fillna('-')
# C:\Users\estoque\AppData\Local\Temp\ipykernel_28316\57950684.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   situacao_final['Descrição'] = situacao_final['Descrição'].fillna('-')

# %%
curva_abc_geral.to_excel('dados_tratados\curva_abc_geral.xlsx')
curva_abc_frac.to_excel('dados_tratados\curva_abc_frac.xlsx')
curva_abc_cx.to_excel('dados_tratados\curva_abc_cx.xlsx')
situacao_final.to_excel('dados_tratados\situacao_final.xlsx')
